# %%
import torch
import torch.optim as optim
import numpy as np
import os
import argparse
import time, datetime
import matplotlib; matplotlib.use('Agg')
from src import config, data
from src.checkpoints import CheckpointIO
from collections import defaultdict
import shutil
from tensorboardX import SummaryWriter

# %%
writer = SummaryWriter('testrun')
cfg = config.load_config('configs/pointcloud/grid.yaml', 'configs/default.yaml')
is_cuda = (torch.cuda.is_available())
device = torch.device("cuda:1" if is_cuda else "cpu")

# %%
print(device)
# Out:
# cuda:1

# %%
t0 = time.time()

# Shorthands
out_dir = cfg['training']['out_dir']
batch_size = cfg['training']['batch_size']
backup_every = cfg['training']['backup_every']
vis_n_outputs = cfg['generation']['vis_n_outputs']

# %%
# Output directory
if not os.path.exists(out_dir):
    os.makedirs(out_dir)

shutil.copyfile('configs/pointcloud/grid.yaml', os.path.join(out_dir, 'config.yaml'))

# Dataset
train_dataset = config.get_dataset('train', cfg)
val_dataset = config.get_dataset('val', cfg, return_idx=True)

# %%
shape = train_dataset[0]

# %%
# train_loader = torch.utils.data.DataLoader(
#     train_dataset[5], batch_size=batch_size, num_workers=cfg['training']['n_workers'], shuffle=True,
#     collate_fn=data.collate_remove_none,
#     worker_init_fn=data.worker_init_fn)

# print(len(train_loader))    
# print(train_loader)

# val_loader = torch.utils.data.DataLoader(
#     val_dataset, batch_size=1, num_workers=cfg['training']['n_workers_val'], shuffle=False,
#      collate_fn=data.collate_remove_none,
#      worker_init_fn=data.worker_init_fn)

# %%
# code subset
train_dataset = config.get_dataset("train", cfg)
ds = torch.utils.data.Subset(train_dataset, indices= [0]*len(train_dataset))
val_dataset = config.get_dataset("val", cfg)
val_ds = torch.utils.data.Subset(val_dataset, indices= [0]*len(val_dataset))
train_loader = torch.utils.data.DataLoader(
    ds, batch_size=32, num_workers=8, shuffle=True,
    collate_fn=data.collate_remove_none,
    worker_init_fn=data.worker_init_fn)
# val_loader = torch.utils.data.DataLoader(
#     ds, batch_size=1, num_workers=8, shuffle=True,
#     collate_fn=data.collate_remove_none,
#     worker_init_fn=data.worker_init_fn)

# %%
# Model
model = config.get_model(cfg, device=device, dataset=train_dataset)

# Generator
generator = config.get_generator(model, cfg, device=device)

# Intialize training
optimizer = optim.Adam(model.parameters(), lr=1e-4)
# optimizer = optim.SGD(model.parameters(), lr=1e-4, momentum=0.9)
trainer = config.get_trainer(model, optimizer, cfg, device=device)

checkpoint_io = CheckpointIO(out_dir, model=model, optimizer=optimizer)
# try:
#     load_dict = checkpoint_io.load('model.pt')
# except FileExistsError:
#     load_dict = dict()
# epoch_it = load_dict.get('epoch_it', 0)
# it = load_dict.get('it', 0)
# metric_val_best = load_dict.get(
#      'loss_val_best', -model_selection_sign * np.inf)

# if metric_val_best == np.inf or metric_val_best == -np.inf:
#     metric_val_best = -model_selection_sign * np.inf
# print('Current best validation metric (%s): %.8f'
#       % (model_selection_metric, metric_val_best))

# %%
# Shorthands
print_every = cfg['training']['print_every']
checkpoint_every = cfg['training']['checkpoint_every']
validate_every = cfg['training']['validate_every']
visualize_every = cfg['training']['visualize_every']

# Print model
nparameters = sum(p.numel() for p in model.parameters())
print('Total number of parameters: %d' % nparameters)

print('output path: ', cfg['training']['out_dir'])
# Out:
# Total number of parameters: 1978275
# output path:  out/pointcloud/grid

# %%
#batch = next(train_loader.__iter__())

# %%
# c = model.encode_inputs(batch.get('inputs').cuda())
# results = model.decode(batch.get('points').cuda(), c).logits

# %%
it = 0
epoch_it = 0
batch = next(train_loader.__iter__())
while epoch_it <= 30000:
    epoch_it += 1

    it += 1
    loss = trainer.train_step(batch)
    #logger.add_scalar('train/loss', loss, it)
    writer.add_scalars("metropolis+sigma0.1", {'global_loss':loss[0],
                                        'norm_loss':loss[1],
                                        'gradient_loss':loss[2], 
                                        'ratio_relu':loss[3]}, it)
    
    
    #writer.add_scalar("dotProductReg", loss[0], it)
    # Print output
    if print_every > 0 and (it % print_every) == 0:
        t = datetime.datetime.now()
        print('[Epoch %02d] it=%03d, loss=%.4f, time: %.2fs, %02d:%02d'
                    % (epoch_it, it, loss[0], time.time() - t0, t.hour, t.minute))

    #data_v = next(in data_vis_.__iter__())ist:
    # Visualize output
#     if visualize_every > 0 and (it % visualize_every) == 0:
#         print('Visualizing')
#         for data_vis in data_vis_list:
#             if cfg['generation']['sliding_window']:
#                 out = generator.generate_mesh_sliding(data_vis['data'])
#             else:
#                 out = generator.generate_mesh(data_vis['data'])
#             # Get statistics
#             try:
#                 mesh, stats_dict = out
#             except TypeError:
#                 mesh, stats_dict = out, {}

#             mesh.export(os.path.join(out_dir, 'vis', '{}_{}_{}.off'.format(it, data_vis['category'], data_vis['it'])))


    # Save checkpoint
    if (checkpoint_every > 0 and (it % checkpoint_every) == 0):
        print('Saving checkpoint')
        checkpoint_io.save('metropolis+sigma0.1.pt', epoch_it=epoch_it, it=it)

    # Backup if necessary
    if (backup_every > 0 and (it % backup_every) == 0):
        print('Backup checkpoint')
        checkpoint_io.save('metropolis+sigma0.1Model_%d.pt' % it, epoch_it=epoch_it, it=it)
        
    # Run validation
#     if validate_every > 0 and (it % validate_every) == 0:
#         eval_dict = trainer.evaluate(val_loader)
#         metric_val = eval_dict[model_selection_metric]
#         print('Validation metric (%s): %.4f'
#                 % (model_selection_metric, metric_val))

#         for k, v in eval_dict.items():
#             logger.add_scalar('val/%s' % k, v, it)

#         if model_selection_sign * (metric_val - metric_val_best) > 0:
#             metric_val_best = metric_val
#             print('New best model (loss %.4f)' % metric_val_best)
#             checkpoint_io.save('model_best.pt', epoch_it=epoch_it, it=it,
#                                 loss_val_best=metric_val_best)

    # Exit if necessary
#     if exit_after > 0 and (time.time() - t0) >= exit_after:
#         print('Time limit reached. Exiting.')
#         checkpoint_io.save('model.pt', epoch_it=epoch_it, it=it,
#                             loss_val_best=metric_val_best)

#print(train_loader)
# Out:
# /home/nizar/miniconda3/envs/conv_onet/lib/python3.6/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# [Epoch 100] it=100, loss=0.5443, time: 73.70s, 11:00
# [Epoch 200] it=200, loss=0.6636, time: 133.53s, 11:01
# Saving checkpoint
# [Epoch 300] it=300, loss=0.8100, time: 193.87s, 11:02
# [Epoch 400] it=400, loss=0.8754, time: 253.91s, 11:03
# Saving checkpoint
# [Epoch 500] it=500, loss=0.9108, time: 313.96s, 11:04
# [Epoch 600] it=600, loss=0.9362, time: 373.96s, 11:05
# Saving checkpoint
# [Epoch 700] it=700, loss=0.9575, time: 434.49s, 11:06
# [Epoch 800] it=800, loss=0.9777, time: 494.35s, 11:07
# Saving checkpoint
# [Epoch 900] it=900, loss=0.9811, time: 554.37s, 11:08
# [Epoch 1000] it=1000, loss=0.9956, time: 614.31s, 11:09
# Saving checkpoint
# [Epoch 1100] it=1100, loss=0.9966, time: 675.08s, 11:10
# [Epoch 1200] it=1200, loss=0.9936, time: 735.82s, 11:11
# Saving checkpoint
# [Epoch 1300] it=1300, loss=0.9899, time: 796.20s, 11:12
# [Epoch 1400] it=1400, loss=0.9870, time: 855.24s, 11:13
# Saving checkpoint
# [Epoch 1500] it=1500, loss=0.9854, time: 914.35s, 11:14
# [Epoch 1600] it=1600, loss=0.9816, time: 973.43s, 11:15
# Saving checkpoint
# [Epoch 1700] it=1700, loss=0.9790, time: 1032.53s, 11:16
# [Epoch 1800] it=1800, loss=0.9778, time: 1091.60s, 11:17
# Saving checkpoint
# [Epoch 1900] it=1900, loss=0.9768, time: 1150.69s, 11:18
# [Epoch 2000] it=2000, loss=0.9756, time: 1209.72s, 11:19
# Saving checkpoint
# [Epoch 2100] it=2100, loss=0.9750, time: 1268.80s, 11:20
# [Epoch 2200] it=2200, loss=0.9773, time: 1327.85s, 11:21
# Saving checkpoint
# [Epoch 2300] it=2300, loss=0.9762, time: 1386.98s, 11:22
# [Epoch 2400] it=2400, loss=0.9762, time: 1446.03s, 11:23
# Saving checkpoint
# [Epoch 2500] it=2500, loss=0.9754, time: 1505.15s, 11:24
# [Epoch 2600] it=2600, loss=0.9765, time: 1564.08s, 11:25
# Saving checkpoint
# [Epoch 2700] it=2700, loss=0.9766, time: 1623.11s, 11:26
# [Epoch 2800] it=2800, loss=0.9763, time: 1681.77s, 11:27
# Saving checkpoint
# [Epoch 2900] it=2900, loss=0.9767, time: 1740.82s, 11:28
# [Epoch 3000] it=3000, loss=0.9787, time: 1800.31s, 11:29
# Saving checkpoint
# [Epoch 3100] it=3100, loss=0.9785, time: 1859.55s, 11:30
# [Epoch 3200] it=3200, loss=0.9794, time: 1918.60s, 11:31
# Saving checkpoint
# [Epoch 3300] it=3300, loss=0.9804, time: 1977.85s, 11:32
# [Epoch 3400] it=3400, loss=0.9782, time: 2034.63s, 11:33
# Saving checkpoint
# [Epoch 3500] it=3500, loss=0.9803, time: 2094.06s, 11:34
# [Epoch 3600] it=3600, loss=0.9804, time: 2153.16s, 11:35
# Saving checkpoint
# [Epoch 3700] it=3700, loss=0.9814, time: 2212.25s, 11:36
# [Epoch 3800] it=3800, loss=0.9816, time: 2271.06s, 11:37
# Saving checkpoint
# [Epoch 3900] it=3900, loss=0.9815, time: 2330.24s, 11:38
# [Epoch 4000] it=4000, loss=0.9824, time: 2389.80s, 11:39
# Saving checkpoint
# Backup checkpoint
# [Epoch 4100] it=4100, loss=0.9820, time: 2449.45s, 11:40
# [Epoch 4200] it=4200, loss=0.9828, time: 2508.43s, 11:41
# Saving checkpoint
# [Epoch 4300] it=4300, loss=0.9834, time: 2567.46s, 11:42
# [Epoch 4400] it=4400, loss=0.9819, time: 2626.41s, 11:43
# Saving checkpoint
# [Epoch 4500] it=4500, loss=0.9838, time: 2685.34s, 11:44
# [Epoch 4600] it=4600, loss=0.9845, time: 2742.73s, 11:45
# Saving checkpoint
# [Epoch 4700] it=4700, loss=0.9843, time: 2796.75s, 11:46
# [Epoch 4800] it=4800, loss=0.9832, time: 2850.67s, 11:46
# Saving checkpoint
# [Epoch 4900] it=4900, loss=0.9858, time: 2904.65s, 11:47
# [Epoch 5000] it=5000, loss=0.9843, time: 2958.56s, 11:48
# Saving checkpoint
# [Epoch 5100] it=5100, loss=0.9853, time: 3017.50s, 11:49
# [Epoch 5200] it=5200, loss=0.9853, time: 3074.45s, 11:50
# Saving checkpoint
# [Epoch 5300] it=5300, loss=0.9872, time: 3133.44s, 11:51
# [Epoch 5400] it=5400, loss=0.9850, time: 3192.41s, 11:52
# Saving checkpoint
# [Epoch 5500] it=5500, loss=0.9866, time: 3251.45s, 11:53
# [Epoch 5600] it=5600, loss=0.9870, time: 3310.17s, 11:54
# Saving checkpoint
# [Epoch 5700] it=5700, loss=0.9859, time: 3369.16s, 11:55
# [Epoch 5800] it=5800, loss=0.9854, time: 3428.17s, 11:56
# Saving checkpoint
# [Epoch 5900] it=5900, loss=0.9873, time: 3487.27s, 11:57
# [Epoch 6000] it=6000, loss=0.9872, time: 3546.29s, 11:58
# Saving checkpoint
# [Epoch 6100] it=6100, loss=0.9893, time: 3605.53s, 11:59
# [Epoch 6200] it=6200, loss=0.9879, time: 3665.25s, 12:00
# Saving checkpoint
# [Epoch 6300] it=6300, loss=0.9873, time: 3724.45s, 12:01
# [Epoch 6400] it=6400, loss=0.9876, time: 3783.46s, 12:02
# Saving checkpoint
# [Epoch 6500] it=6500, loss=0.9906, time: 3842.42s, 12:03
# [Epoch 6600] it=6600, loss=0.9912, time: 3901.25s, 12:04
# Saving checkpoint
# [Epoch 6700] it=6700, loss=0.9877, time: 3960.37s, 12:05
# [Epoch 6800] it=6800, loss=0.9892, time: 4019.45s, 12:06
# Saving checkpoint
# [Epoch 6900] it=6900, loss=0.9886, time: 4078.60s, 12:07
# [Epoch 7000] it=7000, loss=0.9905, time: 4137.71s, 12:08
# Saving checkpoint
# [Epoch 7100] it=7100, loss=0.9896, time: 4196.82s, 12:09
# [Epoch 7200] it=7200, loss=0.9901, time: 4255.84s, 12:10
# Saving checkpoint
# [Epoch 7300] it=7300, loss=0.9889, time: 4314.97s, 12:11
# [Epoch 7400] it=7400, loss=0.9917, time: 4373.97s, 12:12
# Saving checkpoint
# [Epoch 7500] it=7500, loss=0.9909, time: 4433.10s, 12:13
# [Epoch 7600] it=7600, loss=0.9901, time: 4492.13s, 12:14
# Saving checkpoint
# [Epoch 7700] it=7700, loss=0.9901, time: 4551.42s, 12:15
# [Epoch 7800] it=7800, loss=0.9914, time: 4611.25s, 12:16
# Saving checkpoint
# [Epoch 7900] it=7900, loss=0.9891, time: 4671.10s, 12:17
# [Epoch 8000] it=8000, loss=0.9904, time: 4730.96s, 12:18
# Saving checkpoint
# Backup checkpoint
# [Epoch 8100] it=8100, loss=0.9909, time: 4790.22s, 12:19
# [Epoch 8200] it=8200, loss=0.9905, time: 4849.92s, 12:20
# Saving checkpoint
# [Epoch 8300] it=8300, loss=0.9912, time: 4909.13s, 12:21
# [Epoch 8400] it=8400, loss=0.9928, time: 4968.11s, 12:22
# Saving checkpoint
# [Epoch 8500] it=8500, loss=0.9917, time: 5022.51s, 12:23
# [Epoch 8600] it=8600, loss=0.9920, time: 5081.56s, 12:24
# Saving checkpoint
# [Epoch 8700] it=8700, loss=0.9939, time: 5140.52s, 12:25
# [Epoch 8800] it=8800, loss=0.9926, time: 5199.65s, 12:26
# Saving checkpoint
# [Epoch 8900] it=8900, loss=0.9944, time: 5258.81s, 12:27
# [Epoch 9000] it=9000, loss=0.9931, time: 5317.88s, 12:28
# Saving checkpoint
# [Epoch 9100] it=9100, loss=0.9931, time: 5378.10s, 12:29
# [Epoch 9200] it=9200, loss=0.9930, time: 5437.76s, 12:30
# Saving checkpoint
# [Epoch 9300] it=9300, loss=0.9931, time: 5496.42s, 12:30
# [Epoch 9400] it=9400, loss=0.9915, time: 5556.89s, 12:32
# Saving checkpoint
# [Epoch 9500] it=9500, loss=0.9936, time: 5616.08s, 12:32
# [Epoch 9600] it=9600, loss=0.9932, time: 5675.15s, 12:33
# Saving checkpoint
# [Epoch 9700] it=9700, loss=0.9938, time: 5734.26s, 12:34
# [Epoch 9800] it=9800, loss=0.9959, time: 5793.33s, 12:35
# Saving checkpoint
# [Epoch 9900] it=9900, loss=0.9931, time: 5852.48s, 12:36
# [Epoch 10000] it=10000, loss=0.9943, time: 5911.55s, 12:37
# Saving checkpoint
# [Epoch 10100] it=10100, loss=0.9927, time: 5970.66s, 12:38
# [Epoch 10200] it=10200, loss=0.9947, time: 6029.78s, 12:39
# Saving checkpoint
# [Epoch 10300] it=10300, loss=0.9938, time: 6088.86s, 12:40
# [Epoch 10400] it=10400, loss=0.9940, time: 6147.84s, 12:41
# Saving checkpoint
# [Epoch 10500] it=10500, loss=0.9940, time: 6206.94s, 12:42
# [Epoch 10600] it=10600, loss=0.9956, time: 6265.97s, 12:43
# Saving checkpoint
# [Epoch 10700] it=10700, loss=0.9970, time: 6325.05s, 12:44
# [Epoch 10800] it=10800, loss=0.9958, time: 6383.97s, 12:45
# Saving checkpoint
# [Epoch 10900] it=10900, loss=0.9925, time: 6443.47s, 12:46
# [Epoch 11000] it=11000, loss=0.9945, time: 6503.14s, 12:47
# Saving checkpoint
# [Epoch 11100] it=11100, loss=0.9940, time: 6562.31s, 12:48
# [Epoch 11200] it=11200, loss=0.9870, time: 6621.26s, 12:49
# Saving checkpoint
# [Epoch 11300] it=11300, loss=0.9944, time: 6680.32s, 12:50
# [Epoch 11400] it=11400, loss=0.9945, time: 6739.29s, 12:51
# Saving checkpoint
# [Epoch 11500] it=11500, loss=0.9948, time: 6798.34s, 12:52
# [Epoch 11600] it=11600, loss=0.9948, time: 6857.34s, 12:53
# Saving checkpoint
# [Epoch 11700] it=11700, loss=0.9954, time: 6916.37s, 12:54
# [Epoch 11800] it=11800, loss=0.9944, time: 6972.24s, 12:55
# Saving checkpoint
# [Epoch 11900] it=11900, loss=0.9954, time: 7027.94s, 12:56
# [Epoch 12000] it=12000, loss=0.9949, time: 7086.97s, 12:57
# Saving checkpoint
# Backup checkpoint
# [Epoch 12100] it=12100, loss=0.9964, time: 7146.13s, 12:58
# [Epoch 12200] it=12200, loss=0.9954, time: 7205.01s, 12:59
# Saving checkpoint
# [Epoch 12300] it=12300, loss=0.9946, time: 7263.99s, 13:00
# [Epoch 12400] it=12400, loss=0.9976, time: 7323.27s, 13:01
# Saving checkpoint
# [Epoch 12500] it=12500, loss=0.9962, time: 7378.59s, 13:02
# [Epoch 12600] it=12600, loss=0.9952, time: 7432.52s, 13:03
# Saving checkpoint
# [Epoch 12700] it=12700, loss=0.9958, time: 7489.95s, 13:04
# [Epoch 12800] it=12800, loss=0.9956, time: 7548.75s, 13:05
# Saving checkpoint
# [Epoch 12900] it=12900, loss=0.9962, time: 7607.76s, 13:06
# [Epoch 13000] it=13000, loss=0.9952, time: 7666.69s, 13:07
# Saving checkpoint
# [Epoch 13100] it=13100, loss=0.9959, time: 7725.71s, 13:08
# [Epoch 13200] it=13200, loss=0.9992, time: 7784.66s, 13:09
# Saving checkpoint
# [Epoch 13300] it=13300, loss=0.9958, time: 7843.76s, 13:10
# [Epoch 13400] it=13400, loss=0.9965, time: 7902.74s, 13:11
# Saving checkpoint
# [Epoch 13500] it=13500, loss=0.9953, time: 7961.71s, 13:12
# [Epoch 13600] it=13600, loss=0.9963, time: 8020.69s, 13:13
# Saving checkpoint
# [Epoch 13700] it=13700, loss=0.9276, time: 8079.70s, 13:14
# [Epoch 13800] it=13800, loss=0.9355, time: 8138.62s, 13:15
# Saving checkpoint
# [Epoch 13900] it=13900, loss=0.9574, time: 8197.64s, 13:16
# [Epoch 14000] it=14000, loss=0.9696, time: 8256.56s, 13:17
# Saving checkpoint
# [Epoch 14100] it=14100, loss=0.9781, time: 8315.49s, 13:17
# [Epoch 14200] it=14200, loss=0.9821, time: 8374.41s, 13:18
# Saving checkpoint
# [Epoch 14300] it=14300, loss=0.9844, time: 8434.28s, 13:19
# [Epoch 14400] it=14400, loss=0.9860, time: 8493.72s, 13:20
# Saving checkpoint
# [Epoch 14500] it=14500, loss=0.9878, time: 8553.67s, 13:21
# [Epoch 14600] it=14600, loss=0.9894, time: 8614.86s, 13:22
# Saving checkpoint
# [Epoch 14700] it=14700, loss=0.9907, time: 8676.28s, 13:23
# [Epoch 14800] it=14800, loss=0.9919, time: 8735.81s, 13:24
# Saving checkpoint
# [Epoch 14900] it=14900, loss=0.9929, time: 8795.05s, 13:25
# [Epoch 15000] it=15000, loss=0.9936, time: 8854.23s, 13:26
# Saving checkpoint
# [Epoch 15100] it=15100, loss=0.9943, time: 8913.44s, 13:27
# [Epoch 15200] it=15200, loss=0.9948, time: 8972.64s, 13:28
# Saving checkpoint
# [Epoch 15300] it=15300, loss=0.9951, time: 9031.86s, 13:29
# [Epoch 15400] it=15400, loss=0.9957, time: 9091.00s, 13:30
# Saving checkpoint
# [Epoch 15500] it=15500, loss=0.9961, time: 9150.46s, 13:31
# [Epoch 15600] it=15600, loss=0.9962, time: 9209.63s, 13:32
# Saving checkpoint
# [Epoch 15700] it=15700, loss=0.9964, time: 9268.89s, 13:33
# [Epoch 15800] it=15800, loss=0.9964, time: 9327.93s, 13:34
# Saving checkpoint
# [Epoch 15900] it=15900, loss=0.9965, time: 9387.23s, 13:35
# [Epoch 16000] it=16000, loss=0.9967, time: 9446.57s, 13:36
# Saving checkpoint
# Backup checkpoint
# [Epoch 16100] it=16100, loss=0.9965, time: 9506.06s, 13:37
# [Epoch 16200] it=16200, loss=0.9966, time: 9565.38s, 13:38
# Saving checkpoint
# [Epoch 16300] it=16300, loss=0.9963, time: 9625.06s, 13:39
# [Epoch 16400] it=16400, loss=0.9961, time: 9684.45s, 13:40
# Saving checkpoint
# [Epoch 16500] it=16500, loss=0.9960, time: 9743.86s, 13:41
# [Epoch 16600] it=16600, loss=0.9957, time: 9802.85s, 13:42
# Saving checkpoint
# [Epoch 16700] it=16700, loss=0.9956, time: 9861.98s, 13:43
# [Epoch 16800] it=16800, loss=0.9955, time: 9921.01s, 13:44
# Saving checkpoint
# [Epoch 16900] it=16900, loss=0.9954, time: 9980.65s, 13:45
# [Epoch 17000] it=17000, loss=0.9954, time: 10040.25s, 13:46
# Saving checkpoint
# [Epoch 17100] it=17100, loss=0.9953, time: 10099.32s, 13:47
# [Epoch 17200] it=17200, loss=0.9953, time: 10158.23s, 13:48
# Saving checkpoint
# [Epoch 17300] it=17300, loss=0.9954, time: 10217.22s, 13:49
# [Epoch 17400] it=17400, loss=0.9953, time: 10276.17s, 13:50
# Saving checkpoint
# [Epoch 17500] it=17500, loss=0.9955, time: 10335.18s, 13:51
# [Epoch 17600] it=17600, loss=0.9959, time: 10394.13s, 13:52
# Saving checkpoint
# [Epoch 17700] it=17700, loss=0.9960, time: 10452.99s, 13:53
# [Epoch 17800] it=17800, loss=0.9960, time: 10511.78s, 13:54
# Saving checkpoint
# [Epoch 17900] it=17900, loss=0.9965, time: 10570.84s, 13:55
# [Epoch 18000] it=18000, loss=0.9964, time: 10629.77s, 13:56
# Saving checkpoint
# [Epoch 18100] it=18100, loss=0.9963, time: 10688.96s, 13:57
# [Epoch 18200] it=18200, loss=0.9964, time: 10748.31s, 13:58
# Saving checkpoint
# [Epoch 18300] it=18300, loss=0.9965, time: 10807.50s, 13:59
# [Epoch 18400] it=18400, loss=0.9966, time: 10866.83s, 14:00
# Saving checkpoint
# [Epoch 18500] it=18500, loss=0.9964, time: 10925.80s, 14:01
# [Epoch 18600] it=18600, loss=0.9966, time: 10984.66s, 14:02
# Saving checkpoint
# [Epoch 18700] it=18700, loss=0.9966, time: 11043.67s, 14:03
# [Epoch 18800] it=18800, loss=0.9967, time: 11102.59s, 14:04
# Saving checkpoint
# [Epoch 18900] it=18900, loss=0.9967, time: 11161.57s, 14:05
# [Epoch 19000] it=19000, loss=0.9968, time: 11220.44s, 14:06
# Saving checkpoint
# [Epoch 19100] it=19100, loss=0.9970, time: 11279.38s, 14:07
# [Epoch 19200] it=19200, loss=0.9967, time: 11338.36s, 14:08
# Saving checkpoint
# [Epoch 19300] it=19300, loss=0.9971, time: 11399.15s, 14:09
# [Epoch 19400] it=19400, loss=0.9969, time: 11459.76s, 14:10
# Saving checkpoint
# [Epoch 19500] it=19500, loss=0.9972, time: 11518.92s, 14:11
# [Epoch 19600] it=19600, loss=0.9971, time: 11577.92s, 14:12
# Saving checkpoint
# [Epoch 19700] it=19700, loss=0.9974, time: 11636.91s, 14:13
# [Epoch 19800] it=19800, loss=0.9971, time: 11695.89s, 14:14
# Saving checkpoint
# [Epoch 19900] it=19900, loss=0.9972, time: 11755.51s, 14:15
# [Epoch 20000] it=20000, loss=0.9972, time: 11815.01s, 14:16
# Saving checkpoint
# Backup checkpoint
# [Epoch 20100] it=20100, loss=0.9975, time: 11874.84s, 14:17
# [Epoch 20200] it=20200, loss=0.9974, time: 11933.73s, 14:18
# Saving checkpoint
# [Epoch 20300] it=20300, loss=0.9973, time: 11992.57s, 14:19
# [Epoch 20400] it=20400, loss=0.9976, time: 12051.49s, 14:20
# Saving checkpoint
# [Epoch 20500] it=20500, loss=0.9977, time: 12110.59s, 14:21
# [Epoch 20600] it=20600, loss=0.9977, time: 12169.62s, 14:22
# Saving checkpoint
# [Epoch 20700] it=20700, loss=0.9974, time: 12228.72s, 14:23
# [Epoch 20800] it=20800, loss=0.9974, time: 12287.96s, 14:24
# Saving checkpoint
# [Epoch 20900] it=20900, loss=0.9977, time: 12347.13s, 14:25
# [Epoch 21000] it=21000, loss=0.9977, time: 12406.55s, 14:26
# Saving checkpoint
# [Epoch 21100] it=21100, loss=0.9973, time: 12465.73s, 14:27
# [Epoch 21200] it=21200, loss=0.9976, time: 12524.69s, 14:28
# Saving checkpoint
# [Epoch 21300] it=21300, loss=0.9973, time: 12583.74s, 14:29
# [Epoch 21400] it=21400, loss=0.9975, time: 12642.76s, 14:30
# Saving checkpoint
# [Epoch 21500] it=21500, loss=0.9975, time: 12701.87s, 14:31
# [Epoch 21600] it=21600, loss=0.9977, time: 12760.33s, 14:32
# Saving checkpoint
# [Epoch 21700] it=21700, loss=0.9976, time: 12818.85s, 14:33
# [Epoch 21800] it=21800, loss=0.9976, time: 12878.08s, 14:34
# Saving checkpoint
# [Epoch 21900] it=21900, loss=0.9975, time: 12937.14s, 14:35
# [Epoch 22000] it=22000, loss=0.9978, time: 12996.53s, 14:35
# Saving checkpoint
# [Epoch 22100] it=22100, loss=0.9976, time: 13055.81s, 14:36
# [Epoch 22200] it=22200, loss=0.9978, time: 13111.12s, 14:37
# Saving checkpoint
# [Epoch 22300] it=22300, loss=0.9978, time: 13165.09s, 14:38
# [Epoch 22400] it=22400, loss=0.9979, time: 13219.03s, 14:39
# Saving checkpoint
# [Epoch 22500] it=22500, loss=0.9981, time: 13275.44s, 14:40
# [Epoch 22600] it=22600, loss=0.9982, time: 13334.70s, 14:41
# Saving checkpoint
# [Epoch 22700] it=22700, loss=0.9982, time: 13393.54s, 14:42
# [Epoch 22800] it=22800, loss=0.9983, time: 13452.39s, 14:43
# Saving checkpoint
# [Epoch 22900] it=22900, loss=0.9980, time: 13511.95s, 14:44
# [Epoch 23000] it=23000, loss=0.9981, time: 13571.00s, 14:45
# Saving checkpoint
# [Epoch 23100] it=23100, loss=0.9985, time: 13630.06s, 14:46
# [Epoch 23200] it=23200, loss=0.9982, time: 13688.82s, 14:47
# Saving checkpoint
# [Epoch 23300] it=23300, loss=0.9980, time: 13747.68s, 14:48
# [Epoch 23400] it=23400, loss=0.9982, time: 13806.62s, 14:49
# Saving checkpoint
# [Epoch 23500] it=23500, loss=0.9979, time: 13865.63s, 14:50
# [Epoch 23600] it=23600, loss=0.9978, time: 13924.72s, 14:51
# Saving checkpoint
# [Epoch 23700] it=23700, loss=0.9984, time: 13983.78s, 14:52
# [Epoch 23800] it=23800, loss=0.9983, time: 14042.74s, 14:53
# Saving checkpoint
# [Epoch 23900] it=23900, loss=0.9982, time: 14101.85s, 14:54
# [Epoch 24000] it=24000, loss=0.9985, time: 14160.84s, 14:55
# Saving checkpoint
# Backup checkpoint
# [Epoch 24100] it=24100, loss=0.9983, time: 14220.07s, 14:56
# [Epoch 24200] it=24200, loss=0.9984, time: 14278.94s, 14:57
# Saving checkpoint
# [Epoch 24300] it=24300, loss=0.9989, time: 14338.00s, 14:58
# [Epoch 24400] it=24400, loss=0.9988, time: 14396.99s, 14:59
# Saving checkpoint
# [Epoch 24500] it=24500, loss=0.9985, time: 14456.13s, 15:00
# [Epoch 24600] it=24600, loss=0.9983, time: 14516.42s, 15:01
# Saving checkpoint
# [Epoch 24700] it=24700, loss=0.9988, time: 14577.31s, 15:02
# [Epoch 24800] it=24800, loss=0.9987, time: 14638.37s, 15:03
# Saving checkpoint
# [Epoch 24900] it=24900, loss=0.9992, time: 14699.48s, 15:04
# [Epoch 25000] it=25000, loss=0.9983, time: 14760.52s, 15:05
# Saving checkpoint
# [Epoch 25100] it=25100, loss=0.9988, time: 14821.71s, 15:06
# [Epoch 25200] it=25200, loss=0.9987, time: 14882.71s, 15:07
# Saving checkpoint
# [Epoch 25300] it=25300, loss=0.9991, time: 14941.51s, 15:08
# [Epoch 25400] it=25400, loss=0.9988, time: 15000.22s, 15:09
# Saving checkpoint
# [Epoch 25500] it=25500, loss=0.9986, time: 15059.24s, 15:10
# [Epoch 25600] it=25600, loss=0.9989, time: 15118.25s, 15:11
# Saving checkpoint
# [Epoch 25700] it=25700, loss=0.9985, time: 15177.31s, 15:12
# [Epoch 25800] it=25800, loss=0.9988, time: 15236.31s, 15:13
# Saving checkpoint
# [Epoch 25900] it=25900, loss=0.9987, time: 15295.67s, 15:14
# [Epoch 26000] it=26000, loss=0.9988, time: 15354.81s, 15:15
# Saving checkpoint
# [Epoch 26100] it=26100, loss=0.9988, time: 15413.93s, 15:16
# [Epoch 26200] it=26200, loss=0.9985, time: 15472.70s, 15:17
# Saving checkpoint
# [Epoch 26300] it=26300, loss=0.9985, time: 15531.75s, 15:18
# [Epoch 26400] it=26400, loss=0.9993, time: 15590.73s, 15:19
# Saving checkpoint
# [Epoch 26500] it=26500, loss=0.9985, time: 15649.74s, 15:20
# [Epoch 26600] it=26600, loss=0.9990, time: 15708.65s, 15:21
# Saving checkpoint
# [Epoch 26700] it=26700, loss=0.9987, time: 15767.70s, 15:22
# [Epoch 26800] it=26800, loss=0.9986, time: 15826.32s, 15:23
# Saving checkpoint
# [Epoch 26900] it=26900, loss=0.9987, time: 15885.11s, 15:24
# [Epoch 27000] it=27000, loss=0.9982, time: 15944.04s, 15:25
# Saving checkpoint
# [Epoch 27100] it=27100, loss=0.9985, time: 16003.15s, 15:26
# [Epoch 27200] it=27200, loss=0.9986, time: 16062.24s, 15:27
# Saving checkpoint
# [Epoch 27300] it=27300, loss=0.9985, time: 16121.41s, 15:28
# [Epoch 27400] it=27400, loss=0.9985, time: 16180.32s, 15:29
# Saving checkpoint
# [Epoch 27500] it=27500, loss=0.9980, time: 16239.40s, 15:30
# [Epoch 27600] it=27600, loss=0.9985, time: 16298.42s, 15:31
# Saving checkpoint
# [Epoch 27700] it=27700, loss=0.9985, time: 16357.60s, 15:32
# [Epoch 27800] it=27800, loss=0.9985, time: 16416.91s, 15:33
# Saving checkpoint
# [Epoch 27900] it=27900, loss=0.9987, time: 16475.96s, 15:33
# [Epoch 28000] it=28000, loss=0.9991, time: 16535.05s, 15:34
# Saving checkpoint
# Backup checkpoint
# [Epoch 28100] it=28100, loss=0.9983, time: 16594.27s, 15:35
# [Epoch 28200] it=28200, loss=0.9985, time: 16653.25s, 15:36
# Saving checkpoint
# [Epoch 28300] it=28300, loss=0.9984, time: 16712.18s, 15:37
# [Epoch 28400] it=28400, loss=0.9987, time: 16770.86s, 15:38
# Saving checkpoint
# [Epoch 28500] it=28500, loss=0.9987, time: 16829.93s, 15:39
# [Epoch 28600] it=28600, loss=0.9987, time: 16888.88s, 15:40
# Saving checkpoint
# [Epoch 28700] it=28700, loss=0.9988, time: 16947.85s, 15:41
# [Epoch 28800] it=28800, loss=0.9988, time: 17006.89s, 15:42
# Saving checkpoint
# [Epoch 28900] it=28900, loss=0.9987, time: 17065.95s, 15:43
# [Epoch 29000] it=29000, loss=0.9986, time: 17124.92s, 15:44
# Saving checkpoint
# [Epoch 29100] it=29100, loss=0.9988, time: 17183.91s, 15:45
# [Epoch 29200] it=29200, loss=0.9988, time: 17242.88s, 15:46
# Saving checkpoint
# [Epoch 29300] it=29300, loss=0.9989, time: 17301.92s, 15:47
# [Epoch 29400] it=29400, loss=0.9992, time: 17360.87s, 15:48
# Saving checkpoint
# [Epoch 29500] it=29500, loss=0.9988, time: 17419.99s, 15:49
# [Epoch 29600] it=29600, loss=0.9990, time: 17479.28s, 15:50
# Saving checkpoint
# [Epoch 29700] it=29700, loss=0.9986, time: 17538.29s, 15:51
# [Epoch 29800] it=29800, loss=0.9989, time: 17597.37s, 15:52
# Saving checkpoint
# [Epoch 29900] it=29900, loss=0.9989, time: 17656.21s, 15:53
# [Epoch 30000] it=30000, loss=0.9986, time: 17715.23s, 15:54
# Saving checkpoint
