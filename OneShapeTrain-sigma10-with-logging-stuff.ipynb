# %%
import torch
import torch.optim as optim
import numpy as np
import os
import argparse
import time, datetime
import matplotlib; matplotlib.use('Agg')
from src import config, data
from src.checkpoints import CheckpointIO
from collections import defaultdict
import shutil
from tensorboardX import SummaryWriter

# %%
writer = SummaryWriter('testrun')
cfg = config.load_config('configs/pointcloud/grid.yaml', 'configs/default.yaml')
is_cuda = (torch.cuda.is_available())
device = torch.device("cuda:2" if is_cuda else "cpu")

# %%
print(device)
# Out:
# cuda:2

# %%
t0 = time.time()

# Shorthands
out_dir = cfg['training']['out_dir']
batch_size = cfg['training']['batch_size']
backup_every = cfg['training']['backup_every']
vis_n_outputs = cfg['generation']['vis_n_outputs']

# %%
# Output directory
if not os.path.exists(out_dir):
    os.makedirs(out_dir)

shutil.copyfile('configs/pointcloud/grid.yaml', os.path.join(out_dir, 'config.yaml'))

# Dataset
train_dataset = config.get_dataset('train', cfg)
val_dataset = config.get_dataset('val', cfg, return_idx=True)

# %%
shape = train_dataset[0]

# %%
# train_loader = torch.utils.data.DataLoader(
#     train_dataset[5], batch_size=batch_size, num_workers=cfg['training']['n_workers'], shuffle=True,
#     collate_fn=data.collate_remove_none,
#     worker_init_fn=data.worker_init_fn)

# print(len(train_loader))    
# print(train_loader)

# val_loader = torch.utils.data.DataLoader(
#     val_dataset, batch_size=1, num_workers=cfg['training']['n_workers_val'], shuffle=False,
#      collate_fn=data.collate_remove_none,
#      worker_init_fn=data.worker_init_fn)

# %%
# code subset
train_dataset = config.get_dataset("train", cfg)
ds = torch.utils.data.Subset(train_dataset, indices= [0]*len(train_dataset))
val_dataset = config.get_dataset("val", cfg)
val_ds = torch.utils.data.Subset(val_dataset, indices= [0]*len(val_dataset))
train_loader = torch.utils.data.DataLoader(
    ds, batch_size=32, num_workers=8, shuffle=True,
    collate_fn=data.collate_remove_none,
    worker_init_fn=data.worker_init_fn)
# val_loader = torch.utils.data.DataLoader(
#     ds, batch_size=1, num_workers=8, shuffle=True,
#     collate_fn=data.collate_remove_none,
#     worker_init_fn=data.worker_init_fn)

# %%
# Model
model = config.get_model(cfg, device=device, dataset=train_dataset)

# Generator
generator = config.get_generator(model, cfg, device=device)

# Intialize training
optimizer = optim.Adam(model.parameters(), lr=1e-4)
# optimizer = optim.SGD(model.parameters(), lr=1e-4, momentum=0.9)
trainer = config.get_trainer(model, optimizer, cfg, device=device)

checkpoint_io = CheckpointIO(out_dir, model=model, optimizer=optimizer)
# try:
#     load_dict = checkpoint_io.load('model.pt')
# except FileExistsError:
#     load_dict = dict()
# epoch_it = load_dict.get('epoch_it', 0)
# it = load_dict.get('it', 0)
# metric_val_best = load_dict.get(
#      'loss_val_best', -model_selection_sign * np.inf)

# if metric_val_best == np.inf or metric_val_best == -np.inf:
#     metric_val_best = -model_selection_sign * np.inf
# print('Current best validation metric (%s): %.8f'
#       % (model_selection_metric, metric_val_best))

# %%
# Shorthands
print_every = cfg['training']['print_every']
checkpoint_every = cfg['training']['checkpoint_every']
validate_every = cfg['training']['validate_every']
visualize_every = cfg['training']['visualize_every']

# Print model
nparameters = sum(p.numel() for p in model.parameters())
print('Total number of parameters: %d' % nparameters)

print('output path: ', cfg['training']['out_dir'])
# Out:
# Total number of parameters: 1978275
# output path:  out/pointcloud/grid

# %%
#batch = next(train_loader.__iter__())

# %%
# c = model.encode_inputs(batch.get('inputs').cuda())
# results = model.decode(batch.get('points').cuda(), c).logits

# %%
it = 0
epoch_it = 0
batch = next(train_loader.__iter__())
while epoch_it <= 30000:
    epoch_it += 1

    it += 1
    loss = trainer.train_step(batch)
    #logger.add_scalar('train/loss', loss, it)
    writer.add_scalars("metropolis+sigma10", {'global_loss':loss[0],
                                        'norm_loss':loss[1],
                                        'gradient_loss':loss[2], 
                                        'ratio_relu':loss[3]}, it)
    
    
    #writer.add_scalar("dotProductReg", loss[0], it)
    # Print output
    if print_every > 0 and (it % print_every) == 0:
        t = datetime.datetime.now()
        print('[Epoch %02d] it=%03d, loss=%.4f, time: %.2fs, %02d:%02d'
                    % (epoch_it, it, loss[0], time.time() - t0, t.hour, t.minute))

    #data_v = next(in data_vis_.__iter__())ist:
    # Visualize output
#     if visualize_every > 0 and (it % visualize_every) == 0:
#         print('Visualizing')
#         for data_vis in data_vis_list:
#             if cfg['generation']['sliding_window']:
#                 out = generator.generate_mesh_sliding(data_vis['data'])
#             else:
#                 out = generator.generate_mesh(data_vis['data'])
#             # Get statistics
#             try:
#                 mesh, stats_dict = out
#             except TypeError:
#                 mesh, stats_dict = out, {}

#             mesh.export(os.path.join(out_dir, 'vis', '{}_{}_{}.off'.format(it, data_vis['category'], data_vis['it'])))


    # Save checkpoint
    if (checkpoint_every > 0 and (it % checkpoint_every) == 0):
        print('Saving checkpoint')
        checkpoint_io.save('metropolis+sigma10.pt', epoch_it=epoch_it, it=it)

    # Backup if necessary
    if (backup_every > 0 and (it % backup_every) == 0):
        print('Backup checkpoint')
        checkpoint_io.save('metropolis+sigma10Model_%d.pt' % it, epoch_it=epoch_it, it=it)
        
    # Run validation
#     if validate_every > 0 and (it % validate_every) == 0:
#         eval_dict = trainer.evaluate(val_loader)
#         metric_val = eval_dict[model_selection_metric]
#         print('Validation metric (%s): %.4f'
#                 % (model_selection_metric, metric_val))

#         for k, v in eval_dict.items():
#             logger.add_scalar('val/%s' % k, v, it)

#         if model_selection_sign * (metric_val - metric_val_best) > 0:
#             metric_val_best = metric_val
#             print('New best model (loss %.4f)' % metric_val_best)
#             checkpoint_io.save('model_best.pt', epoch_it=epoch_it, it=it,
#                                 loss_val_best=metric_val_best)

    # Exit if necessary
#     if exit_after > 0 and (time.time() - t0) >= exit_after:
#         print('Time limit reached. Exiting.')
#         checkpoint_io.save('model.pt', epoch_it=epoch_it, it=it,
#                             loss_val_best=metric_val_best)

#print(train_loader)
# Out:
# /home/nizar/miniconda3/envs/conv_onet/lib/python3.6/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# [Epoch 100] it=100, loss=-0.0681, time: 74.78s, 11:01
# [Epoch 200] it=200, loss=0.1831, time: 134.57s, 11:02
# Saving checkpoint
# [Epoch 300] it=300, loss=0.0026, time: 194.43s, 11:03
# [Epoch 400] it=400, loss=-0.0886, time: 254.85s, 11:04
# Saving checkpoint
# [Epoch 500] it=500, loss=-0.1231, time: 314.86s, 11:05
# [Epoch 600] it=600, loss=-0.0916, time: 374.26s, 11:06
# Saving checkpoint
# [Epoch 700] it=700, loss=-0.0741, time: 434.08s, 11:07
# [Epoch 800] it=800, loss=-0.0266, time: 495.15s, 11:08
# Saving checkpoint
# [Epoch 900] it=900, loss=-0.0379, time: 555.69s, 11:09
# [Epoch 1000] it=1000, loss=-0.0396, time: 615.41s, 11:10
# Saving checkpoint
# [Epoch 1100] it=1100, loss=0.0009, time: 675.07s, 11:11
# [Epoch 1200] it=1200, loss=0.0381, time: 734.60s, 11:12
# Saving checkpoint
# [Epoch 1300] it=1300, loss=0.0252, time: 794.42s, 11:13
# [Epoch 1400] it=1400, loss=0.0394, time: 854.14s, 11:14
# Saving checkpoint
# [Epoch 1500] it=1500, loss=0.0699, time: 913.93s, 11:15
# [Epoch 1600] it=1600, loss=0.0811, time: 973.60s, 11:16
# Saving checkpoint
# [Epoch 1700] it=1700, loss=0.0926, time: 1033.38s, 11:17
# [Epoch 1800] it=1800, loss=0.0948, time: 1093.09s, 11:18
# Saving checkpoint
# [Epoch 1900] it=1900, loss=0.0621, time: 1152.71s, 11:19
# [Epoch 2000] it=2000, loss=0.0385, time: 1212.33s, 11:20
# Saving checkpoint
# [Epoch 2100] it=2100, loss=0.0365, time: 1272.01s, 11:21
# [Epoch 2200] it=2200, loss=0.0313, time: 1331.61s, 11:22
# Saving checkpoint
# [Epoch 2300] it=2300, loss=0.0461, time: 1391.33s, 11:23
# [Epoch 2400] it=2400, loss=0.0661, time: 1451.62s, 11:24
# Saving checkpoint
# [Epoch 2500] it=2500, loss=0.0807, time: 1512.31s, 11:25
# [Epoch 2600] it=2600, loss=0.0926, time: 1572.33s, 11:26
# Saving checkpoint
# [Epoch 2700] it=2700, loss=0.0670, time: 1631.37s, 11:27
# [Epoch 2800] it=2800, loss=0.0511, time: 1691.45s, 11:28
# Saving checkpoint
# [Epoch 2900] it=2900, loss=0.1032, time: 1753.32s, 11:29
# [Epoch 3000] it=3000, loss=0.0716, time: 1813.44s, 11:30
# Saving checkpoint
# [Epoch 3100] it=3100, loss=0.0520, time: 1875.52s, 11:31
# [Epoch 3200] it=3200, loss=0.0685, time: 1936.89s, 11:32
# Saving checkpoint
# [Epoch 3300] it=3300, loss=0.0531, time: 1997.43s, 11:33
# [Epoch 3400] it=3400, loss=0.0669, time: 2057.86s, 11:35
# Saving checkpoint
# [Epoch 3500] it=3500, loss=0.0365, time: 2117.71s, 11:35
# [Epoch 3600] it=3600, loss=0.0532, time: 2177.86s, 11:37
# Saving checkpoint
# [Epoch 3700] it=3700, loss=0.0813, time: 2238.34s, 11:38
# [Epoch 3800] it=3800, loss=0.0827, time: 2299.47s, 11:39
# Saving checkpoint
# [Epoch 3900] it=3900, loss=0.0552, time: 2359.52s, 11:40
# [Epoch 4000] it=4000, loss=0.0734, time: 2420.80s, 11:41
# Saving checkpoint
# Backup checkpoint
# [Epoch 4100] it=4100, loss=0.1010, time: 2481.05s, 11:42
# [Epoch 4200] it=4200, loss=0.0816, time: 2540.63s, 11:43
# Saving checkpoint
# [Epoch 4300] it=4300, loss=0.0660, time: 2600.32s, 11:44
# [Epoch 4400] it=4400, loss=0.0720, time: 2659.92s, 11:45
# Saving checkpoint
# [Epoch 4500] it=4500, loss=0.1050, time: 2718.82s, 11:46
# [Epoch 4600] it=4600, loss=0.0582, time: 2777.71s, 11:46
# Saving checkpoint
# [Epoch 4700] it=4700, loss=0.0771, time: 2836.72s, 11:47
# [Epoch 4800] it=4800, loss=0.0596, time: 2895.49s, 11:48
# Saving checkpoint
# [Epoch 4900] it=4900, loss=0.0630, time: 2955.38s, 11:49
# [Epoch 5000] it=5000, loss=0.0853, time: 3015.10s, 11:50
# Saving checkpoint
# [Epoch 5100] it=5100, loss=0.1116, time: 3074.71s, 11:51
# [Epoch 5200] it=5200, loss=0.0490, time: 3134.28s, 11:52
# Saving checkpoint
# [Epoch 5300] it=5300, loss=0.0323, time: 3194.03s, 11:53
# [Epoch 5400] it=5400, loss=0.0424, time: 3253.46s, 11:54
# Saving checkpoint
# [Epoch 5500] it=5500, loss=0.0752, time: 3313.14s, 11:55
# [Epoch 5600] it=5600, loss=0.0674, time: 3372.71s, 11:56
# Saving checkpoint
# [Epoch 5700] it=5700, loss=0.0469, time: 3432.26s, 11:57
# [Epoch 5800] it=5800, loss=0.0707, time: 3492.19s, 11:58
# Saving checkpoint
# [Epoch 5900] it=5900, loss=0.0580, time: 3551.81s, 11:59
# [Epoch 6000] it=6000, loss=0.0541, time: 3611.21s, 12:00
# Saving checkpoint
# [Epoch 6100] it=6100, loss=0.0797, time: 3670.67s, 12:01
# [Epoch 6200] it=6200, loss=0.1040, time: 3730.04s, 12:02
# Saving checkpoint
# [Epoch 6300] it=6300, loss=0.0346, time: 3789.41s, 12:03
# [Epoch 6400] it=6400, loss=0.0927, time: 3848.97s, 12:04
# Saving checkpoint
# [Epoch 6500] it=6500, loss=0.0706, time: 3909.29s, 12:05
# [Epoch 6600] it=6600, loss=0.0752, time: 3969.52s, 12:06
# Saving checkpoint
# [Epoch 6700] it=6700, loss=0.0751, time: 4029.43s, 12:07
# [Epoch 6800] it=6800, loss=0.0612, time: 4088.91s, 12:08
# Saving checkpoint
# [Epoch 6900] it=6900, loss=0.0623, time: 4148.47s, 12:09
# [Epoch 7000] it=7000, loss=0.0370, time: 4209.29s, 12:10
# Saving checkpoint
# [Epoch 7100] it=7100, loss=0.0317, time: 4270.10s, 12:11
# [Epoch 7200] it=7200, loss=0.0670, time: 4329.57s, 12:12
# Saving checkpoint
# [Epoch 7300] it=7300, loss=0.0916, time: 4389.12s, 12:13
# [Epoch 7400] it=7400, loss=0.0671, time: 4448.60s, 12:14
# Saving checkpoint
# [Epoch 7500] it=7500, loss=0.0903, time: 4508.11s, 12:15
# [Epoch 7600] it=7600, loss=0.1310, time: 4567.57s, 12:16
# Saving checkpoint
# [Epoch 7700] it=7700, loss=0.1076, time: 4627.07s, 12:17
# [Epoch 7800] it=7800, loss=0.0515, time: 4686.52s, 12:18
# Saving checkpoint
# [Epoch 7900] it=7900, loss=0.0713, time: 4746.06s, 12:19
# [Epoch 8000] it=8000, loss=0.0393, time: 4807.33s, 12:20
# Saving checkpoint
# Backup checkpoint
# [Epoch 8100] it=8100, loss=0.0938, time: 4868.95s, 12:21
# [Epoch 8200] it=8200, loss=0.1007, time: 4928.48s, 12:22
# Saving checkpoint
# [Epoch 8300] it=8300, loss=0.0879, time: 4987.82s, 12:23
# [Epoch 8400] it=8400, loss=0.0962, time: 5048.13s, 12:24
# Saving checkpoint
# [Epoch 8500] it=8500, loss=0.1156, time: 5109.63s, 12:25
# [Epoch 8600] it=8600, loss=0.0821, time: 5170.58s, 12:26
# Saving checkpoint
# [Epoch 8700] it=8700, loss=0.0507, time: 5232.09s, 12:27
# [Epoch 8800] it=8800, loss=0.0883, time: 5292.00s, 12:28
# Saving checkpoint
# [Epoch 8900] it=8900, loss=0.1625, time: 5351.53s, 12:29
# [Epoch 9000] it=9000, loss=0.0697, time: 5410.44s, 12:30
# Saving checkpoint
# [Epoch 9100] it=9100, loss=0.1648, time: 5469.97s, 12:31
# [Epoch 9200] it=9200, loss=0.0752, time: 5529.42s, 12:32
# Saving checkpoint
# [Epoch 9300] it=9300, loss=0.0892, time: 5588.86s, 12:33
# [Epoch 9400] it=9400, loss=0.0741, time: 5648.38s, 12:34
# Saving checkpoint
# [Epoch 9500] it=9500, loss=0.1376, time: 5707.78s, 12:35
# [Epoch 9600] it=9600, loss=0.1147, time: 5767.22s, 12:36
# Saving checkpoint
# [Epoch 9700] it=9700, loss=0.1425, time: 5826.68s, 12:37
# [Epoch 9800] it=9800, loss=0.0806, time: 5886.11s, 12:38
# Saving checkpoint
# [Epoch 9900] it=9900, loss=0.1323, time: 5945.58s, 12:39
# [Epoch 10000] it=10000, loss=0.0824, time: 6004.92s, 12:40
# Saving checkpoint
# [Epoch 10100] it=10100, loss=0.1209, time: 6064.30s, 12:41
# [Epoch 10200] it=10200, loss=0.1477, time: 6123.75s, 12:42
# Saving checkpoint
# [Epoch 10300] it=10300, loss=0.1440, time: 6183.16s, 12:43
# [Epoch 10400] it=10400, loss=0.1241, time: 6242.62s, 12:44
# Saving checkpoint
# [Epoch 10500] it=10500, loss=0.1351, time: 6301.98s, 12:45
# [Epoch 10600] it=10600, loss=0.1304, time: 6361.49s, 12:46
# Saving checkpoint
# [Epoch 10700] it=10700, loss=0.0811, time: 6420.96s, 12:47
# [Epoch 10800] it=10800, loss=0.0836, time: 6481.03s, 12:48
# Saving checkpoint
# [Epoch 10900] it=10900, loss=0.2603, time: 6541.37s, 12:49
# [Epoch 11000] it=11000, loss=0.2746, time: 6601.56s, 12:50
# Saving checkpoint
# [Epoch 11100] it=11100, loss=0.1729, time: 6661.21s, 12:51
# [Epoch 11200] it=11200, loss=0.1611, time: 6720.66s, 12:52
# Saving checkpoint
# [Epoch 11300] it=11300, loss=0.1030, time: 6780.18s, 12:53
# [Epoch 11400] it=11400, loss=0.2441, time: 6839.54s, 12:54
# Saving checkpoint
# [Epoch 11500] it=11500, loss=0.1267, time: 6898.41s, 12:55
# [Epoch 11600] it=11600, loss=0.0648, time: 6957.41s, 12:56
# Saving checkpoint
# [Epoch 11700] it=11700, loss=0.1833, time: 7016.86s, 12:57
# [Epoch 11800] it=11800, loss=0.1752, time: 7076.24s, 12:58
# Saving checkpoint
# [Epoch 11900] it=11900, loss=0.1053, time: 7135.64s, 12:59
# [Epoch 12000] it=12000, loss=0.0923, time: 7195.06s, 13:00
# Saving checkpoint
# Backup checkpoint
# [Epoch 12100] it=12100, loss=0.0992, time: 7254.66s, 13:01
# [Epoch 12200] it=12200, loss=0.0739, time: 7313.36s, 13:02
# Saving checkpoint
# [Epoch 12300] it=12300, loss=-0.0049, time: 7372.04s, 13:03
# [Epoch 12400] it=12400, loss=0.0990, time: 7431.48s, 13:04
# Saving checkpoint
# [Epoch 12500] it=12500, loss=0.0875, time: 7490.60s, 13:05
# [Epoch 12600] it=12600, loss=0.0964, time: 7550.27s, 13:06
# Saving checkpoint
# [Epoch 12700] it=12700, loss=0.0679, time: 7610.09s, 13:07
# [Epoch 12800] it=12800, loss=0.0797, time: 7670.28s, 13:08
# Saving checkpoint
# [Epoch 12900] it=12900, loss=0.0171, time: 7730.17s, 13:09
# [Epoch 13000] it=13000, loss=0.1010, time: 7790.33s, 13:10
# Saving checkpoint
# [Epoch 13100] it=13100, loss=0.1006, time: 7849.78s, 13:11
# [Epoch 13200] it=13200, loss=0.1036, time: 7909.23s, 13:12
# Saving checkpoint
# [Epoch 13300] it=13300, loss=0.2299, time: 7968.88s, 13:13
# [Epoch 13400] it=13400, loss=0.1699, time: 8030.38s, 13:14
# Saving checkpoint
# [Epoch 13500] it=13500, loss=0.1248, time: 8092.03s, 13:15
# [Epoch 13600] it=13600, loss=0.1257, time: 8153.65s, 13:16
# Saving checkpoint
# [Epoch 13700] it=13700, loss=0.0455, time: 8214.64s, 13:17
# [Epoch 13800] it=13800, loss=0.1124, time: 8274.22s, 13:18
# Saving checkpoint
# [Epoch 13900] it=13900, loss=0.0829, time: 8335.67s, 13:19
# [Epoch 14000] it=14000, loss=0.0300, time: 8400.26s, 13:20
# Saving checkpoint
# [Epoch 14100] it=14100, loss=0.1013, time: 8462.70s, 13:21
# [Epoch 14200] it=14200, loss=0.1525, time: 8524.58s, 13:22
# Saving checkpoint
# [Epoch 14300] it=14300, loss=0.1024, time: 8586.40s, 13:23
# [Epoch 14400] it=14400, loss=0.0871, time: 8647.96s, 13:24
# Saving checkpoint
# [Epoch 14500] it=14500, loss=0.1225, time: 8710.38s, 13:25
# [Epoch 14600] it=14600, loss=0.0788, time: 8772.45s, 13:26
# Saving checkpoint
# [Epoch 14700] it=14700, loss=0.0748, time: 8835.03s, 13:27
# [Epoch 14800] it=14800, loss=0.1216, time: 8897.20s, 13:28
# Saving checkpoint
# [Epoch 14900] it=14900, loss=0.1104, time: 8959.10s, 13:30
# [Epoch 15000] it=15000, loss=0.0851, time: 9021.12s, 13:31
# Saving checkpoint
# [Epoch 15100] it=15100, loss=0.0965, time: 9083.26s, 13:32
# [Epoch 15200] it=15200, loss=0.1360, time: 9145.36s, 13:33
# Saving checkpoint
# [Epoch 15300] it=15300, loss=0.1368, time: 9208.06s, 13:34
# [Epoch 15400] it=15400, loss=0.1065, time: 9270.09s, 13:35
# Saving checkpoint
# [Epoch 15500] it=15500, loss=0.1642, time: 9331.99s, 13:36
# [Epoch 15600] it=15600, loss=0.1755, time: 9394.10s, 13:37
# Saving checkpoint
# [Epoch 15700] it=15700, loss=0.1967, time: 9455.58s, 13:38
# [Epoch 15800] it=15800, loss=0.1566, time: 9515.44s, 13:39
# Saving checkpoint
# [Epoch 15900] it=15900, loss=0.2886, time: 9577.06s, 13:40
# [Epoch 16000] it=16000, loss=0.1159, time: 9638.58s, 13:41
# Saving checkpoint
# Backup checkpoint
# [Epoch 16100] it=16100, loss=0.1244, time: 9699.03s, 13:42
# [Epoch 16200] it=16200, loss=0.1073, time: 9758.63s, 13:43
# Saving checkpoint
# [Epoch 16300] it=16300, loss=0.1350, time: 9818.42s, 13:44
# [Epoch 16400] it=16400, loss=0.1772, time: 9877.97s, 13:45
# Saving checkpoint
# [Epoch 16500] it=16500, loss=0.1215, time: 9937.55s, 13:46
# [Epoch 16600] it=16600, loss=0.1370, time: 9997.20s, 13:47
# Saving checkpoint
# [Epoch 16700] it=16700, loss=0.0832, time: 10056.84s, 13:48
# [Epoch 16800] it=16800, loss=0.2910, time: 10116.41s, 13:49
# Saving checkpoint
# [Epoch 16900] it=16900, loss=0.1092, time: 10176.19s, 13:50
# [Epoch 17000] it=17000, loss=0.1004, time: 10235.78s, 13:51
# Saving checkpoint
# [Epoch 17100] it=17100, loss=0.0666, time: 10295.63s, 13:52
# [Epoch 17200] it=17200, loss=0.1202, time: 10355.14s, 13:53
# Saving checkpoint
# [Epoch 17300] it=17300, loss=0.1065, time: 10414.23s, 13:54
# [Epoch 17400] it=17400, loss=0.1609, time: 10473.80s, 13:55
# Saving checkpoint
# [Epoch 17500] it=17500, loss=0.1400, time: 10533.44s, 13:56
# [Epoch 17600] it=17600, loss=0.1283, time: 10593.50s, 13:57
# Saving checkpoint
# [Epoch 17700] it=17700, loss=0.1380, time: 10654.06s, 13:58
# [Epoch 17800] it=17800, loss=0.1905, time: 10713.84s, 13:59
# Saving checkpoint
# [Epoch 17900] it=17900, loss=0.0586, time: 10773.35s, 14:00
# [Epoch 18000] it=18000, loss=0.0807, time: 10833.56s, 14:01
# Saving checkpoint
# [Epoch 18100] it=18100, loss=0.1436, time: 10893.19s, 14:02
# [Epoch 18200] it=18200, loss=0.1788, time: 10952.75s, 14:03
# Saving checkpoint
# [Epoch 18300] it=18300, loss=0.1257, time: 11012.41s, 14:04
# [Epoch 18400] it=18400, loss=0.1307, time: 11072.01s, 14:05
# Saving checkpoint
# [Epoch 18500] it=18500, loss=0.1101, time: 11132.80s, 14:06
# [Epoch 18600] it=18600, loss=0.1673, time: 11192.43s, 14:07
# Saving checkpoint
# [Epoch 18700] it=18700, loss=0.1262, time: 11252.08s, 14:08
# [Epoch 18800] it=18800, loss=0.0946, time: 11311.58s, 14:09
# Saving checkpoint
# [Epoch 18900] it=18900, loss=0.1223, time: 11371.23s, 14:10
# [Epoch 19000] it=19000, loss=0.0892, time: 11430.75s, 14:11
# Saving checkpoint
# [Epoch 19100] it=19100, loss=0.1221, time: 11490.41s, 14:12
# [Epoch 19200] it=19200, loss=0.1059, time: 11549.94s, 14:13
# Saving checkpoint
# [Epoch 19300] it=19300, loss=0.1576, time: 11609.62s, 14:14
# [Epoch 19400] it=19400, loss=0.0317, time: 11669.21s, 14:15
# Saving checkpoint
# [Epoch 19500] it=19500, loss=0.1011, time: 11728.98s, 14:16
# [Epoch 19600] it=19600, loss=0.0882, time: 11788.52s, 14:17
# Saving checkpoint
# [Epoch 19700] it=19700, loss=0.0535, time: 11848.15s, 14:18
# [Epoch 19800] it=19800, loss=0.0494, time: 11907.67s, 14:19
# Saving checkpoint
# [Epoch 19900] it=19900, loss=0.1155, time: 11967.30s, 14:20
# [Epoch 20000] it=20000, loss=0.0917, time: 12027.47s, 14:21
# Saving checkpoint
# Backup checkpoint
# [Epoch 20100] it=20100, loss=0.0953, time: 12087.46s, 14:22
# [Epoch 20200] it=20200, loss=0.0866, time: 12147.85s, 14:23
# Saving checkpoint
# [Epoch 20300] it=20300, loss=0.1117, time: 12210.07s, 14:24
# [Epoch 20400] it=20400, loss=0.1251, time: 12271.84s, 14:25
# Saving checkpoint
# [Epoch 20500] it=20500, loss=0.1482, time: 12332.99s, 14:26
# [Epoch 20600] it=20600, loss=0.1215, time: 12393.76s, 14:27
# Saving checkpoint
# [Epoch 20700] it=20700, loss=0.1858, time: 12454.32s, 14:28
# [Epoch 20800] it=20800, loss=0.0961, time: 12515.01s, 14:29
# Saving checkpoint
# [Epoch 20900] it=20900, loss=0.0998, time: 12575.68s, 14:30
# [Epoch 21000] it=21000, loss=0.0897, time: 12636.30s, 14:31
# Saving checkpoint
# [Epoch 21100] it=21100, loss=0.0896, time: 12695.85s, 14:32
# [Epoch 21200] it=21200, loss=0.0763, time: 12755.07s, 14:33
# Saving checkpoint
# [Epoch 21300] it=21300, loss=0.0599, time: 12814.82s, 14:34
# [Epoch 21400] it=21400, loss=0.0917, time: 12874.38s, 14:35
# Saving checkpoint
# [Epoch 21500] it=21500, loss=0.0996, time: 12934.20s, 14:36
# [Epoch 21600] it=21600, loss=0.1121, time: 12993.84s, 14:37
# Saving checkpoint
# [Epoch 21700] it=21700, loss=0.1634, time: 13053.45s, 14:38
# [Epoch 21800] it=21800, loss=0.0333, time: 13113.03s, 14:39
# Saving checkpoint
# [Epoch 21900] it=21900, loss=0.0625, time: 13172.80s, 14:40
# [Epoch 22000] it=22000, loss=0.1144, time: 13232.70s, 14:41
# Saving checkpoint
# [Epoch 22100] it=22100, loss=0.0889, time: 13292.74s, 14:42
# [Epoch 22200] it=22200, loss=0.0932, time: 13351.94s, 14:43
# Saving checkpoint
# [Epoch 22300] it=22300, loss=0.0950, time: 13411.46s, 14:44
# [Epoch 22400] it=22400, loss=0.1105, time: 13470.89s, 14:45
# Saving checkpoint
# [Epoch 22500] it=22500, loss=0.0669, time: 13530.47s, 14:46
# [Epoch 22600] it=22600, loss=0.0757, time: 13589.85s, 14:47
# Saving checkpoint
# [Epoch 22700] it=22700, loss=0.0992, time: 13648.83s, 14:48
# [Epoch 22800] it=22800, loss=0.0788, time: 13710.15s, 14:49
# Saving checkpoint
# [Epoch 22900] it=22900, loss=0.0412, time: 13771.89s, 14:50
# [Epoch 23000] it=23000, loss=0.0853, time: 13832.99s, 14:51
# Saving checkpoint
# [Epoch 23100] it=23100, loss=0.0661, time: 13893.48s, 14:52
# [Epoch 23200] it=23200, loss=0.0773, time: 13953.46s, 14:53
# Saving checkpoint
# [Epoch 23300] it=23300, loss=0.0750, time: 14013.90s, 14:54
# [Epoch 23400] it=23400, loss=0.0814, time: 14074.59s, 14:55
# Saving checkpoint
# [Epoch 23500] it=23500, loss=0.0948, time: 14136.30s, 14:56
# [Epoch 23600] it=23600, loss=0.0761, time: 14197.98s, 14:57
# Saving checkpoint
# [Epoch 23700] it=23700, loss=0.0516, time: 14258.48s, 14:58
# [Epoch 23800] it=23800, loss=-0.0231, time: 14318.37s, 14:59
# Saving checkpoint
# [Epoch 23900] it=23900, loss=0.0632, time: 14378.14s, 15:00
# [Epoch 24000] it=24000, loss=0.0786, time: 14438.08s, 15:01
# Saving checkpoint
# Backup checkpoint
# [Epoch 24100] it=24100, loss=0.0953, time: 14497.82s, 15:02
# [Epoch 24200] it=24200, loss=0.0503, time: 14558.18s, 15:03
# Saving checkpoint
# [Epoch 24300] it=24300, loss=0.0330, time: 14617.90s, 15:04
# [Epoch 24400] it=24400, loss=0.0423, time: 14677.52s, 15:05
# Saving checkpoint
# [Epoch 24500] it=24500, loss=0.0779, time: 14737.19s, 15:06
# [Epoch 24600] it=24600, loss=0.0600, time: 14796.85s, 15:07
# Saving checkpoint
# [Epoch 24700] it=24700, loss=0.0235, time: 14856.71s, 15:08
# [Epoch 24800] it=24800, loss=0.0581, time: 14915.46s, 15:09
# Saving checkpoint
# [Epoch 24900] it=24900, loss=0.0671, time: 14974.90s, 15:10
# [Epoch 25000] it=25000, loss=0.0383, time: 15034.31s, 15:11
# Saving checkpoint
# [Epoch 25100] it=25100, loss=0.0086, time: 15093.81s, 15:12
# [Epoch 25200] it=25200, loss=0.0851, time: 15153.24s, 15:13
# Saving checkpoint
# [Epoch 25300] it=25300, loss=0.0575, time: 15212.76s, 15:14
# [Epoch 25400] it=25400, loss=0.0889, time: 15272.20s, 15:15
# Saving checkpoint
# [Epoch 25500] it=25500, loss=0.0729, time: 15331.73s, 15:16
# [Epoch 25600] it=25600, loss=0.0459, time: 15390.88s, 15:17
# Saving checkpoint
# [Epoch 25700] it=25700, loss=0.0799, time: 15452.34s, 15:18
# [Epoch 25800] it=25800, loss=-0.0586, time: 15513.77s, 15:19
# Saving checkpoint
# [Epoch 25900] it=25900, loss=0.0107, time: 15575.21s, 15:20
# [Epoch 26000] it=26000, loss=0.0393, time: 15636.65s, 15:21
# Saving checkpoint
# [Epoch 26100] it=26100, loss=0.0270, time: 15698.19s, 15:22
# [Epoch 26200] it=26200, loss=0.0736, time: 15757.57s, 15:23
# Saving checkpoint
# [Epoch 26300] it=26300, loss=0.1012, time: 15817.10s, 15:24
# [Epoch 26400] it=26400, loss=0.0982, time: 15876.48s, 15:25
# Saving checkpoint
# [Epoch 26500] it=26500, loss=0.0691, time: 15936.00s, 15:26
# [Epoch 26600] it=26600, loss=0.0429, time: 15995.39s, 15:27
# Saving checkpoint
# [Epoch 26700] it=26700, loss=0.0649, time: 16054.92s, 15:28
# [Epoch 26800] it=26800, loss=0.1200, time: 16114.32s, 15:29
# Saving checkpoint
# [Epoch 26900] it=26900, loss=0.0591, time: 16173.87s, 15:30
# [Epoch 27000] it=27000, loss=0.1536, time: 16233.31s, 15:31
# Saving checkpoint
# [Epoch 27100] it=27100, loss=0.0936, time: 16292.75s, 15:32
# [Epoch 27200] it=27200, loss=0.0991, time: 16352.07s, 15:33
# Saving checkpoint
# [Epoch 27300] it=27300, loss=0.1353, time: 16411.67s, 15:34
# [Epoch 27400] it=27400, loss=0.0808, time: 16471.06s, 15:35
# Saving checkpoint
# [Epoch 27500] it=27500, loss=0.0273, time: 16530.60s, 15:36
# [Epoch 27600] it=27600, loss=0.0442, time: 16590.02s, 15:37
# Saving checkpoint
# [Epoch 27700] it=27700, loss=0.0200, time: 16649.75s, 15:38
# [Epoch 27800] it=27800, loss=0.1054, time: 16708.99s, 15:39
# Saving checkpoint
# [Epoch 27900] it=27900, loss=0.0326, time: 16769.33s, 15:40
# [Epoch 28000] it=28000, loss=0.0339, time: 16829.79s, 15:41
# Saving checkpoint
# Backup checkpoint
# [Epoch 28100] it=28100, loss=0.0982, time: 16889.34s, 15:42
# [Epoch 28200] it=28200, loss=0.0528, time: 16950.28s, 15:43
# Saving checkpoint
# [Epoch 28300] it=28300, loss=0.0902, time: 17011.87s, 15:44
# [Epoch 28400] it=28400, loss=0.0242, time: 17073.34s, 15:45
# Saving checkpoint
# [Epoch 28500] it=28500, loss=0.0406, time: 17134.94s, 15:46
# [Epoch 28600] it=28600, loss=0.0933, time: 17195.07s, 15:47
# Saving checkpoint
# [Epoch 28700] it=28700, loss=0.0976, time: 17254.63s, 15:48
# [Epoch 28800] it=28800, loss=0.1049, time: 17314.06s, 15:49
# Saving checkpoint
# [Epoch 28900] it=28900, loss=0.0844, time: 17373.60s, 15:50
# [Epoch 29000] it=29000, loss=0.0648, time: 17432.32s, 15:51
# Saving checkpoint
# [Epoch 29100] it=29100, loss=0.1170, time: 17491.15s, 15:52
# [Epoch 29200] it=29200, loss=0.1160, time: 17550.64s, 15:53
# Saving checkpoint
# [Epoch 29300] it=29300, loss=0.1254, time: 17609.92s, 15:54
# [Epoch 29400] it=29400, loss=0.0465, time: 17669.35s, 15:55
# Saving checkpoint
# [Epoch 29500] it=29500, loss=0.0800, time: 17728.83s, 15:56
# [Epoch 29600] it=29600, loss=0.0630, time: 17788.10s, 15:57
# Saving checkpoint
# [Epoch 29700] it=29700, loss=0.0517, time: 17847.41s, 15:58
# [Epoch 29800] it=29800, loss=0.1055, time: 17906.57s, 15:59
# Saving checkpoint
# [Epoch 29900] it=29900, loss=0.0265, time: 17966.05s, 16:00
# [Epoch 30000] it=30000, loss=0.1534, time: 18025.38s, 16:01
# Saving checkpoint
