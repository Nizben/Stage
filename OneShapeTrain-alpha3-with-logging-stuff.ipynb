# %%
import torch
import torch.optim as optim
import numpy as np
import os
import argparse
import time, datetime
import matplotlib; matplotlib.use('Agg')
from src import config, data
from src.checkpoints import CheckpointIO
from collections import defaultdict
import shutil
from tensorboardX import SummaryWriter

# %%
writer = SummaryWriter('testrun')
cfg = config.load_config('configs/pointcloud/grid.yaml', 'configs/default.yaml')
is_cuda = (torch.cuda.is_available())
device = torch.device("cuda:3" if is_cuda else "cpu")

# %%
print(device)
# Out:
# cuda:3

# %%
t0 = time.time()

# Shorthands
out_dir = cfg['training']['out_dir']
batch_size = cfg['training']['batch_size']
backup_every = cfg['training']['backup_every']
vis_n_outputs = cfg['generation']['vis_n_outputs']

# %%
# Output directory
if not os.path.exists(out_dir):
    os.makedirs(out_dir)

shutil.copyfile('configs/pointcloud/grid.yaml', os.path.join(out_dir, 'config.yaml'))

# Dataset
train_dataset = config.get_dataset('train', cfg)
val_dataset = config.get_dataset('val', cfg, return_idx=True)

# %%
shape = train_dataset[0]

# %%
# train_loader = torch.utils.data.DataLoader(
#     train_dataset[5], batch_size=batch_size, num_workers=cfg['training']['n_workers'], shuffle=True,
#     collate_fn=data.collate_remove_none,
#     worker_init_fn=data.worker_init_fn)

# print(len(train_loader))    
# print(train_loader)

# val_loader = torch.utils.data.DataLoader(
#     val_dataset, batch_size=1, num_workers=cfg['training']['n_workers_val'], shuffle=False,
#      collate_fn=data.collate_remove_none,
#      worker_init_fn=data.worker_init_fn)

# %%
# code subset
train_dataset = config.get_dataset("train", cfg)
ds = torch.utils.data.Subset(train_dataset, indices= [0]*len(train_dataset))
val_dataset = config.get_dataset("val", cfg)
val_ds = torch.utils.data.Subset(val_dataset, indices= [0]*len(val_dataset))
train_loader = torch.utils.data.DataLoader(
    ds, batch_size=32, num_workers=8, shuffle=True,
    collate_fn=data.collate_remove_none,
    worker_init_fn=data.worker_init_fn)
# val_loader = torch.utils.data.DataLoader(
#     ds, batch_size=1, num_workers=8, shuffle=True,
#     collate_fn=data.collate_remove_none,
#     worker_init_fn=data.worker_init_fn)

# %%
# Model
model = config.get_model(cfg, device=device, dataset=train_dataset)

# Generator
generator = config.get_generator(model, cfg, device=device)

# Intialize training
optimizer = optim.Adam(model.parameters(), lr=1e-4)
# optimizer = optim.SGD(model.parameters(), lr=1e-4, momentum=0.9)
trainer = config.get_trainer(model, optimizer, cfg, device=device)

checkpoint_io = CheckpointIO(out_dir, model=model, optimizer=optimizer)
# try:
#     load_dict = checkpoint_io.load('model.pt')
# except FileExistsError:
#     load_dict = dict()
# epoch_it = load_dict.get('epoch_it', 0)
# it = load_dict.get('it', 0)
# metric_val_best = load_dict.get(
#      'loss_val_best', -model_selection_sign * np.inf)

# if metric_val_best == np.inf or metric_val_best == -np.inf:
#     metric_val_best = -model_selection_sign * np.inf
# print('Current best validation metric (%s): %.8f'
#       % (model_selection_metric, metric_val_best))

# %%
# Shorthands
print_every = cfg['training']['print_every']
checkpoint_every = cfg['training']['checkpoint_every']
validate_every = cfg['training']['validate_every']
visualize_every = cfg['training']['visualize_every']

# Print model
nparameters = sum(p.numel() for p in model.parameters())
print('Total number of parameters: %d' % nparameters)

print('output path: ', cfg['training']['out_dir'])
# Out:
# Total number of parameters: 1978275
# output path:  out/pointcloud/grid

# %%
#batch = next(train_loader.__iter__())

# %%
# c = model.encode_inputs(batch.get('inputs').cuda())
# results = model.decode(batch.get('points').cuda(), c).logits

# %%
it = 0
epoch_it = 0
batch = next(train_loader.__iter__())
while epoch_it <= 30000:
    epoch_it += 1

    it += 1
    loss = trainer.train_step(batch)
    #logger.add_scalar('train/loss', loss, it)
    writer.add_scalars("metropolis+alpha3", {'global_loss':loss[0],
                                        'norm_loss':loss[1],
                                        'gradient_loss':loss[2], 
                                        'ratio_relu':loss[3]}, it)
    
    
    #writer.add_scalar("dotProductReg", loss[0], it)
    # Print output
    if print_every > 0 and (it % print_every) == 0:
        t = datetime.datetime.now()
        print('[Epoch %02d] it=%03d, loss=%.4f, time: %.2fs, %02d:%02d'
                    % (epoch_it, it, loss[0], time.time() - t0, t.hour, t.minute))

    #data_v = next(in data_vis_.__iter__())ist:
    # Visualize output
#     if visualize_every > 0 and (it % visualize_every) == 0:
#         print('Visualizing')
#         for data_vis in data_vis_list:
#             if cfg['generation']['sliding_window']:
#                 out = generator.generate_mesh_sliding(data_vis['data'])
#             else:
#                 out = generator.generate_mesh(data_vis['data'])
#             # Get statistics
#             try:
#                 mesh, stats_dict = out
#             except TypeError:
#                 mesh, stats_dict = out, {}

#             mesh.export(os.path.join(out_dir, 'vis', '{}_{}_{}.off'.format(it, data_vis['category'], data_vis['it'])))


    # Save checkpoint
    if (checkpoint_every > 0 and (it % checkpoint_every) == 0):
        print('Saving checkpoint')
        checkpoint_io.save('metropolis+alpha3.pt', epoch_it=epoch_it, it=it)

    # Backup if necessary
    if (backup_every > 0 and (it % backup_every) == 0):
        print('Backup checkpoint')
        checkpoint_io.save('metropolis+alpha3Model_%d.pt' % it, epoch_it=epoch_it, it=it)
        
    # Run validation
#     if validate_every > 0 and (it % validate_every) == 0:
#         eval_dict = trainer.evaluate(val_loader)
#         metric_val = eval_dict[model_selection_metric]
#         print('Validation metric (%s): %.4f'
#                 % (model_selection_metric, metric_val))

#         for k, v in eval_dict.items():
#             logger.add_scalar('val/%s' % k, v, it)

#         if model_selection_sign * (metric_val - metric_val_best) > 0:
#             metric_val_best = metric_val
#             print('New best model (loss %.4f)' % metric_val_best)
#             checkpoint_io.save('model_best.pt', epoch_it=epoch_it, it=it,
#                                 loss_val_best=metric_val_best)

    # Exit if necessary
#     if exit_after > 0 and (time.time() - t0) >= exit_after:
#         print('Time limit reached. Exiting.')
#         checkpoint_io.save('model.pt', epoch_it=epoch_it, it=it,
#                             loss_val_best=metric_val_best)

#print(train_loader)
# Out:
# /home/nizar/miniconda3/envs/conv_onet/lib/python3.6/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# [Epoch 100] it=100, loss=0.4960, time: 76.56s, 11:02
# [Epoch 200] it=200, loss=0.2091, time: 137.07s, 11:03
# Saving checkpoint
# [Epoch 300] it=300, loss=0.2461, time: 198.73s, 11:04
# [Epoch 400] it=400, loss=0.3454, time: 260.58s, 11:05
# Saving checkpoint
# [Epoch 500] it=500, loss=0.4349, time: 322.24s, 11:06
# [Epoch 600] it=600, loss=0.2511, time: 383.04s, 11:07
# Saving checkpoint
# [Epoch 700] it=700, loss=0.3772, time: 443.97s, 11:08
# [Epoch 800] it=800, loss=0.2953, time: 504.71s, 11:09
# Saving checkpoint
# [Epoch 900] it=900, loss=0.3069, time: 565.56s, 11:10
# [Epoch 1000] it=1000, loss=0.2989, time: 626.23s, 11:11
# Saving checkpoint
# [Epoch 1100] it=1100, loss=0.1976, time: 687.34s, 11:12
# [Epoch 1200] it=1200, loss=0.2556, time: 748.86s, 11:13
# Saving checkpoint
# [Epoch 1300] it=1300, loss=0.1744, time: 810.49s, 11:14
# [Epoch 1400] it=1400, loss=0.2116, time: 871.37s, 11:15
# Saving checkpoint
# [Epoch 1500] it=1500, loss=0.1364, time: 932.31s, 11:16
# [Epoch 1600] it=1600, loss=0.2038, time: 992.82s, 11:17
# Saving checkpoint
# [Epoch 1700] it=1700, loss=0.1374, time: 1054.39s, 11:19
# [Epoch 1800] it=1800, loss=0.1160, time: 1115.98s, 11:20
# Saving checkpoint
# [Epoch 1900] it=1900, loss=0.1569, time: 1176.92s, 11:21
# [Epoch 2000] it=2000, loss=0.1008, time: 1237.64s, 11:22
# Saving checkpoint
# [Epoch 2100] it=2100, loss=0.1045, time: 1298.45s, 11:23
# [Epoch 2200] it=2200, loss=0.2097, time: 1359.26s, 11:24
# Saving checkpoint
# [Epoch 2300] it=2300, loss=0.0379, time: 1419.97s, 11:25
# [Epoch 2400] it=2400, loss=0.1002, time: 1479.61s, 11:26
# Saving checkpoint
# [Epoch 2500] it=2500, loss=0.1418, time: 1539.41s, 11:27
# [Epoch 2600] it=2600, loss=0.0869, time: 1599.31s, 11:28
# Saving checkpoint
# [Epoch 2700] it=2700, loss=0.0117, time: 1659.33s, 11:29
# [Epoch 2800] it=2800, loss=0.0387, time: 1719.32s, 11:30
# Saving checkpoint
# [Epoch 2900] it=2900, loss=0.0806, time: 1779.12s, 11:31
# [Epoch 3000] it=3000, loss=0.0869, time: 1839.04s, 11:32
# Saving checkpoint
# [Epoch 3100] it=3100, loss=0.0512, time: 1898.73s, 11:33
# [Epoch 3200] it=3200, loss=0.0289, time: 1958.56s, 11:34
# Saving checkpoint
# [Epoch 3300] it=3300, loss=0.0756, time: 2018.40s, 11:35
# [Epoch 3400] it=3400, loss=0.1890, time: 2078.18s, 11:36
# Saving checkpoint
# [Epoch 3500] it=3500, loss=0.1296, time: 2138.37s, 11:37
# [Epoch 3600] it=3600, loss=0.1219, time: 2198.22s, 11:38
# Saving checkpoint
# [Epoch 3700] it=3700, loss=0.0642, time: 2258.16s, 11:39
# [Epoch 3800] it=3800, loss=0.0964, time: 2317.91s, 11:40
# Saving checkpoint
# [Epoch 3900] it=3900, loss=0.0595, time: 2377.77s, 11:41
# [Epoch 4000] it=4000, loss=0.0565, time: 2437.58s, 11:42
# Saving checkpoint
# Backup checkpoint
# [Epoch 4100] it=4100, loss=0.0453, time: 2497.48s, 11:43
# [Epoch 4200] it=4200, loss=0.0077, time: 2557.22s, 11:44
# Saving checkpoint
# [Epoch 4300] it=4300, loss=-0.0392, time: 2616.81s, 11:45
# [Epoch 4400] it=4400, loss=-0.0761, time: 2676.03s, 11:46
# Saving checkpoint
# [Epoch 4500] it=4500, loss=-0.0488, time: 2735.35s, 11:47
# [Epoch 4600] it=4600, loss=0.0748, time: 2794.52s, 11:48
# Saving checkpoint
# [Epoch 4700] it=4700, loss=-0.0144, time: 2853.94s, 11:49
# [Epoch 4800] it=4800, loss=0.0407, time: 2913.66s, 11:49
# Saving checkpoint
# [Epoch 4900] it=4900, loss=-0.0047, time: 2973.22s, 11:50
# [Epoch 5000] it=5000, loss=-0.0271, time: 3033.01s, 11:51
# Saving checkpoint
# [Epoch 5100] it=5100, loss=-0.0317, time: 3092.75s, 11:52
# [Epoch 5200] it=5200, loss=0.0533, time: 3152.41s, 11:53
# Saving checkpoint
# [Epoch 5300] it=5300, loss=0.0177, time: 3212.19s, 11:54
# [Epoch 5400] it=5400, loss=0.0048, time: 3271.95s, 11:55
# Saving checkpoint
# [Epoch 5500] it=5500, loss=0.0203, time: 3331.79s, 11:56
# [Epoch 5600] it=5600, loss=-0.0149, time: 3391.50s, 11:57
# Saving checkpoint
# [Epoch 5700] it=5700, loss=-0.0450, time: 3451.29s, 11:58
# [Epoch 5800] it=5800, loss=-0.0113, time: 3510.98s, 11:59
# Saving checkpoint
# [Epoch 5900] it=5900, loss=0.0298, time: 3570.72s, 12:00
# [Epoch 6000] it=6000, loss=0.0122, time: 3630.41s, 12:01
# Saving checkpoint
# [Epoch 6100] it=6100, loss=0.0190, time: 3690.14s, 12:02
# [Epoch 6200] it=6200, loss=-0.0228, time: 3749.86s, 12:03
# Saving checkpoint
# [Epoch 6300] it=6300, loss=0.0535, time: 3809.64s, 12:04
# [Epoch 6400] it=6400, loss=0.0931, time: 3869.38s, 12:05
# Saving checkpoint
# [Epoch 6500] it=6500, loss=0.0446, time: 3929.35s, 12:06
# [Epoch 6600] it=6600, loss=0.1214, time: 3989.19s, 12:07
# Saving checkpoint
# [Epoch 6700] it=6700, loss=0.0301, time: 4049.02s, 12:08
# [Epoch 6800] it=6800, loss=0.0961, time: 4108.90s, 12:09
# Saving checkpoint
# [Epoch 6900] it=6900, loss=0.0317, time: 4168.84s, 12:10
# [Epoch 7000] it=7000, loss=0.0005, time: 4228.60s, 12:11
# Saving checkpoint
# [Epoch 7100] it=7100, loss=0.1250, time: 4288.49s, 12:12
# [Epoch 7200] it=7200, loss=0.0912, time: 4348.40s, 12:13
# Saving checkpoint
# [Epoch 7300] it=7300, loss=0.0060, time: 4408.38s, 12:14
# [Epoch 7400] it=7400, loss=0.0298, time: 4468.29s, 12:15
# Saving checkpoint
# [Epoch 7500] it=7500, loss=0.0564, time: 4528.33s, 12:16
# [Epoch 7600] it=7600, loss=0.0808, time: 4588.30s, 12:17
# Saving checkpoint
# [Epoch 7700] it=7700, loss=0.1009, time: 4648.33s, 12:18
# [Epoch 7800] it=7800, loss=-0.1220, time: 4708.27s, 12:19
# Saving checkpoint
# [Epoch 7900] it=7900, loss=0.2119, time: 4768.30s, 12:20
# [Epoch 8000] it=8000, loss=-0.0428, time: 4828.33s, 12:21
# Saving checkpoint
# Backup checkpoint
# [Epoch 8100] it=8100, loss=0.0602, time: 4888.09s, 12:22
# [Epoch 8200] it=8200, loss=-0.0227, time: 4947.98s, 12:23
# Saving checkpoint
# [Epoch 8300] it=8300, loss=-0.0018, time: 5008.03s, 12:24
# [Epoch 8400] it=8400, loss=-0.0292, time: 5068.18s, 12:25
# Saving checkpoint
# [Epoch 8500] it=8500, loss=-0.0197, time: 5128.35s, 12:26
# [Epoch 8600] it=8600, loss=0.0624, time: 5188.49s, 12:27
# Saving checkpoint
# [Epoch 8700] it=8700, loss=-0.0444, time: 5248.62s, 12:28
# [Epoch 8800] it=8800, loss=-0.0483, time: 5308.81s, 12:29
# Saving checkpoint
# [Epoch 8900] it=8900, loss=0.0223, time: 5368.97s, 12:30
# [Epoch 9000] it=9000, loss=0.0470, time: 5429.04s, 12:31
# Saving checkpoint
# [Epoch 9100] it=9100, loss=-0.0035, time: 5488.97s, 12:32
# [Epoch 9200] it=9200, loss=0.1015, time: 5548.77s, 12:33
# Saving checkpoint
# [Epoch 9300] it=9300, loss=0.0461, time: 5608.67s, 12:34
# [Epoch 9400] it=9400, loss=0.3424, time: 5668.36s, 12:35
# Saving checkpoint
# [Epoch 9500] it=9500, loss=0.1140, time: 5728.09s, 12:36
# [Epoch 9600] it=9600, loss=0.2343, time: 5787.67s, 12:37
# Saving checkpoint
# [Epoch 9700] it=9700, loss=0.2093, time: 5847.36s, 12:38
# [Epoch 9800] it=9800, loss=0.0330, time: 5906.96s, 12:39
# Saving checkpoint
# [Epoch 9900] it=9900, loss=0.0185, time: 5966.73s, 12:40
# [Epoch 10000] it=10000, loss=0.1254, time: 6026.48s, 12:41
# Saving checkpoint
# [Epoch 10100] it=10100, loss=0.1095, time: 6086.43s, 12:42
# [Epoch 10200] it=10200, loss=0.0972, time: 6146.09s, 12:43
# Saving checkpoint
# [Epoch 10300] it=10300, loss=0.0597, time: 6205.88s, 12:44
# [Epoch 10400] it=10400, loss=-0.0225, time: 6265.52s, 12:45
# Saving checkpoint
# [Epoch 10500] it=10500, loss=0.2376, time: 6325.30s, 12:46
# [Epoch 10600] it=10600, loss=0.0054, time: 6384.99s, 12:47
# Saving checkpoint
# [Epoch 10700] it=10700, loss=0.0637, time: 6444.79s, 12:48
# [Epoch 10800] it=10800, loss=-0.0126, time: 6504.41s, 12:49
# Saving checkpoint
# [Epoch 10900] it=10900, loss=0.3183, time: 6564.16s, 12:50
# [Epoch 11000] it=11000, loss=0.1335, time: 6623.86s, 12:51
# Saving checkpoint
# [Epoch 11100] it=11100, loss=-0.0118, time: 6683.52s, 12:52
# [Epoch 11200] it=11200, loss=0.1886, time: 6743.31s, 12:53
# Saving checkpoint
# [Epoch 11300] it=11300, loss=0.0672, time: 6803.07s, 12:54
# [Epoch 11400] it=11400, loss=0.0440, time: 6862.33s, 12:55
# Saving checkpoint
# [Epoch 11500] it=11500, loss=0.1034, time: 6921.87s, 12:56
# [Epoch 11600] it=11600, loss=0.0621, time: 6981.61s, 12:57
# Saving checkpoint
# [Epoch 11700] it=11700, loss=-0.1842, time: 7041.28s, 12:58
# [Epoch 11800] it=11800, loss=0.0505, time: 7100.88s, 12:59
# Saving checkpoint
# [Epoch 11900] it=11900, loss=0.0877, time: 7160.52s, 13:00
# [Epoch 12000] it=12000, loss=0.2929, time: 7220.15s, 13:01
# Saving checkpoint
# Backup checkpoint
# [Epoch 12100] it=12100, loss=0.2184, time: 7279.29s, 13:02
# [Epoch 12200] it=12200, loss=-0.0223, time: 7338.51s, 13:03
# Saving checkpoint
# [Epoch 12300] it=12300, loss=0.0587, time: 7398.39s, 13:04
# [Epoch 12400] it=12400, loss=0.0004, time: 7458.08s, 13:05
# Saving checkpoint
# [Epoch 12500] it=12500, loss=0.0476, time: 7517.88s, 13:06
# [Epoch 12600] it=12600, loss=0.0755, time: 7577.67s, 13:07
# Saving checkpoint
# [Epoch 12700] it=12700, loss=0.0604, time: 7637.46s, 13:08
# [Epoch 12800] it=12800, loss=-0.0230, time: 7697.21s, 13:09
# Saving checkpoint
# [Epoch 12900] it=12900, loss=-0.0106, time: 7757.09s, 13:10
# [Epoch 13000] it=13000, loss=0.0598, time: 7816.81s, 13:11
# Saving checkpoint
# [Epoch 13100] it=13100, loss=0.0869, time: 7876.74s, 13:12
# [Epoch 13200] it=13200, loss=-0.5495, time: 7936.45s, 13:13
# Saving checkpoint
# [Epoch 13300] it=13300, loss=0.4181, time: 7996.19s, 13:14
# [Epoch 13400] it=13400, loss=-0.0060, time: 8055.91s, 13:15
# Saving checkpoint
# [Epoch 13500] it=13500, loss=-0.1405, time: 8115.76s, 13:16
# [Epoch 13600] it=13600, loss=0.0473, time: 8175.41s, 13:17
# Saving checkpoint
# [Epoch 13700] it=13700, loss=-0.3003, time: 8235.35s, 13:18
# [Epoch 13800] it=13800, loss=0.0505, time: 8295.46s, 13:19
# Saving checkpoint
# [Epoch 13900] it=13900, loss=0.1143, time: 8355.79s, 13:20
# [Epoch 14000] it=14000, loss=0.0842, time: 8416.02s, 13:21
# Saving checkpoint
# [Epoch 14100] it=14100, loss=-0.5610, time: 8476.26s, 13:22
# [Epoch 14200] it=14200, loss=0.1062, time: 8536.35s, 13:23
# Saving checkpoint
# [Epoch 14300] it=14300, loss=-0.0737, time: 8596.42s, 13:24
# [Epoch 14400] it=14400, loss=0.1440, time: 8656.48s, 13:25
# Saving checkpoint
# [Epoch 14500] it=14500, loss=-0.2571, time: 8716.76s, 13:26
# [Epoch 14600] it=14600, loss=0.1024, time: 8777.00s, 13:27
# Saving checkpoint
# [Epoch 14700] it=14700, loss=0.4774, time: 8837.05s, 13:28
# [Epoch 14800] it=14800, loss=0.0506, time: 8897.08s, 13:29
# Saving checkpoint
# [Epoch 14900] it=14900, loss=0.1046, time: 8957.22s, 13:30
# [Epoch 15000] it=15000, loss=0.0633, time: 9017.25s, 13:31
# Saving checkpoint
# [Epoch 15100] it=15100, loss=0.3253, time: 9077.46s, 13:32
# [Epoch 15200] it=15200, loss=0.0121, time: 9137.74s, 13:33
# Saving checkpoint
# [Epoch 15300] it=15300, loss=-0.1816, time: 9197.83s, 13:34
# [Epoch 15400] it=15400, loss=0.0864, time: 9257.85s, 13:35
# Saving checkpoint
# [Epoch 15500] it=15500, loss=0.0435, time: 9318.00s, 13:36
# [Epoch 15600] it=15600, loss=0.1030, time: 9377.98s, 13:37
# Saving checkpoint
# [Epoch 15700] it=15700, loss=0.1053, time: 9437.96s, 13:38
# [Epoch 15800] it=15800, loss=0.0799, time: 9497.69s, 13:39
# Saving checkpoint
# [Epoch 15900] it=15900, loss=0.1089, time: 9557.73s, 13:40
# [Epoch 16000] it=16000, loss=0.2961, time: 9617.67s, 13:41
# Saving checkpoint
# Backup checkpoint
# [Epoch 16100] it=16100, loss=0.0619, time: 9677.51s, 13:42
# [Epoch 16200] it=16200, loss=0.0744, time: 9737.28s, 13:43
# Saving checkpoint
# [Epoch 16300] it=16300, loss=-0.0105, time: 9797.19s, 13:44
# [Epoch 16400] it=16400, loss=0.0565, time: 9857.02s, 13:45
# Saving checkpoint
# [Epoch 16500] it=16500, loss=0.0124, time: 9916.79s, 13:46
# [Epoch 16600] it=16600, loss=0.0819, time: 9976.60s, 13:47
# Saving checkpoint
# [Epoch 16700] it=16700, loss=-0.1625, time: 10036.39s, 13:48
# [Epoch 16800] it=16800, loss=-0.0110, time: 10096.19s, 13:49
# Saving checkpoint
# [Epoch 16900] it=16900, loss=0.0955, time: 10156.00s, 13:50
# [Epoch 17000] it=17000, loss=0.0055, time: 10215.63s, 13:51
# Saving checkpoint
# [Epoch 17100] it=17100, loss=-0.4807, time: 10275.42s, 13:52
# [Epoch 17200] it=17200, loss=0.0414, time: 10333.16s, 13:53
# Saving checkpoint
# [Epoch 17300] it=17300, loss=0.0597, time: 10390.18s, 13:54
# [Epoch 17400] it=17400, loss=0.1578, time: 10449.91s, 13:55
# Saving checkpoint
# [Epoch 17500] it=17500, loss=0.0729, time: 10509.63s, 13:56
# [Epoch 17600] it=17600, loss=0.0267, time: 10569.31s, 13:57
# Saving checkpoint
# [Epoch 17700] it=17700, loss=0.0561, time: 10629.25s, 13:58
# [Epoch 17800] it=17800, loss=0.0308, time: 10688.87s, 13:59
# Saving checkpoint
# [Epoch 17900] it=17900, loss=-0.3811, time: 10748.49s, 14:00
# [Epoch 18000] it=18000, loss=0.0107, time: 10806.41s, 14:01
# Saving checkpoint
# [Epoch 18100] it=18100, loss=-0.0068, time: 10866.10s, 14:02
# [Epoch 18200] it=18200, loss=-0.2995, time: 10925.79s, 14:03
# Saving checkpoint
# [Epoch 18300] it=18300, loss=0.1317, time: 10985.50s, 14:04
# [Epoch 18400] it=18400, loss=0.0735, time: 11045.09s, 14:05
# Saving checkpoint
# [Epoch 18500] it=18500, loss=0.0040, time: 11104.87s, 14:06
# [Epoch 18600] it=18600, loss=-0.5025, time: 11164.61s, 14:07
# Saving checkpoint
# [Epoch 18700] it=18700, loss=0.5429, time: 11224.45s, 14:08
# [Epoch 18800] it=18800, loss=-0.0836, time: 11284.26s, 14:09
# Saving checkpoint
# [Epoch 18900] it=18900, loss=-0.0651, time: 11344.01s, 14:10
# [Epoch 19000] it=19000, loss=0.0721, time: 11403.79s, 14:11
# Saving checkpoint
# [Epoch 19100] it=19100, loss=0.1467, time: 11463.59s, 14:12
# [Epoch 19200] it=19200, loss=0.0847, time: 11523.27s, 14:13
# Saving checkpoint
# [Epoch 19300] it=19300, loss=0.1169, time: 11583.11s, 14:14
# [Epoch 19400] it=19400, loss=0.1603, time: 11642.75s, 14:15
# Saving checkpoint
# [Epoch 19500] it=19500, loss=0.0880, time: 11702.57s, 14:16
# [Epoch 19600] it=19600, loss=0.0900, time: 11762.19s, 14:17
# Saving checkpoint
# [Epoch 19700] it=19700, loss=-0.1015, time: 11821.98s, 14:18
# [Epoch 19800] it=19800, loss=0.0315, time: 11881.60s, 14:19
# Saving checkpoint
# [Epoch 19900] it=19900, loss=0.0306, time: 11941.40s, 14:20
# [Epoch 20000] it=20000, loss=0.0413, time: 12001.29s, 14:21
# Saving checkpoint
# Backup checkpoint
# [Epoch 20100] it=20100, loss=0.0550, time: 12061.12s, 14:22
# [Epoch 20200] it=20200, loss=0.0800, time: 12121.11s, 14:23
# Saving checkpoint
# [Epoch 20300] it=20300, loss=0.0447, time: 12181.28s, 14:24
# [Epoch 20400] it=20400, loss=0.0789, time: 12241.17s, 14:25
# Saving checkpoint
# [Epoch 20500] it=20500, loss=-0.0516, time: 12301.03s, 14:26
# [Epoch 20600] it=20600, loss=0.1264, time: 12360.90s, 14:27
# Saving checkpoint
# [Epoch 20700] it=20700, loss=0.4337, time: 12420.85s, 14:28
# [Epoch 20800] it=20800, loss=0.0193, time: 12480.85s, 14:29
# Saving checkpoint
# [Epoch 20900] it=20900, loss=0.0749, time: 12540.85s, 14:30
# [Epoch 21000] it=21000, loss=0.0291, time: 12596.92s, 14:31
# Saving checkpoint
# [Epoch 21100] it=21100, loss=0.0708, time: 12651.33s, 14:32
# [Epoch 21200] it=21200, loss=0.0412, time: 12706.84s, 14:33
# Saving checkpoint
# [Epoch 21300] it=21300, loss=0.0536, time: 12766.90s, 14:34
# [Epoch 21400] it=21400, loss=0.0749, time: 12826.87s, 14:35
# Saving checkpoint
# [Epoch 21500] it=21500, loss=0.0611, time: 12886.87s, 14:36
# [Epoch 21600] it=21600, loss=0.0906, time: 12946.92s, 14:37
# Saving checkpoint
# [Epoch 21700] it=21700, loss=0.0884, time: 13006.38s, 14:38
# [Epoch 21800] it=21800, loss=0.0248, time: 13065.65s, 14:39
# Saving checkpoint
# [Epoch 21900] it=21900, loss=-0.0012, time: 13124.99s, 14:40
# [Epoch 22000] it=22000, loss=0.0786, time: 13184.74s, 14:41
# Saving checkpoint
# [Epoch 22100] it=22100, loss=0.0497, time: 13244.67s, 14:42
# [Epoch 22200] it=22200, loss=-0.0809, time: 13304.44s, 14:43
# Saving checkpoint
# [Epoch 22300] it=22300, loss=0.0832, time: 13364.38s, 14:44
# [Epoch 22400] it=22400, loss=0.0044, time: 13424.19s, 14:45
# Saving checkpoint
# [Epoch 22500] it=22500, loss=0.2035, time: 13484.24s, 14:46
# [Epoch 22600] it=22600, loss=0.0645, time: 13544.18s, 14:47
# Saving checkpoint
# [Epoch 22700] it=22700, loss=0.0687, time: 13604.11s, 14:48
# [Epoch 22800] it=22800, loss=0.0237, time: 13663.89s, 14:49
# Saving checkpoint
# [Epoch 22900] it=22900, loss=0.1281, time: 13723.70s, 14:50
# [Epoch 23000] it=23000, loss=-0.3219, time: 13783.47s, 14:51
# Saving checkpoint
# [Epoch 23100] it=23100, loss=0.0167, time: 13843.36s, 14:52
# [Epoch 23200] it=23200, loss=0.0460, time: 13903.27s, 14:53
# Saving checkpoint
# [Epoch 23300] it=23300, loss=0.0820, time: 13963.30s, 14:54
# [Epoch 23400] it=23400, loss=-0.0984, time: 14023.24s, 14:55
# Saving checkpoint
# [Epoch 23500] it=23500, loss=0.0640, time: 14083.38s, 14:56
# [Epoch 23600] it=23600, loss=0.0800, time: 14143.48s, 14:57
# Saving checkpoint
# [Epoch 23700] it=23700, loss=-0.0421, time: 14203.35s, 14:58
# [Epoch 23800] it=23800, loss=-0.1781, time: 14263.16s, 14:59
# Saving checkpoint
# [Epoch 23900] it=23900, loss=-0.1084, time: 14323.01s, 15:00
# [Epoch 24000] it=24000, loss=0.0437, time: 14382.84s, 15:01
# Saving checkpoint
# Backup checkpoint
# [Epoch 24100] it=24100, loss=0.0682, time: 14442.80s, 15:02
# [Epoch 24200] it=24200, loss=0.0523, time: 14502.66s, 15:03
# Saving checkpoint
# [Epoch 24300] it=24300, loss=-0.0522, time: 14562.57s, 15:04
# [Epoch 24400] it=24400, loss=0.0288, time: 14622.22s, 15:05
# Saving checkpoint
# [Epoch 24500] it=24500, loss=-0.1407, time: 14681.94s, 15:06
# [Epoch 24600] it=24600, loss=0.0801, time: 14741.54s, 15:07
# Saving checkpoint
# [Epoch 24700] it=24700, loss=0.0446, time: 14801.35s, 15:08
# [Epoch 24800] it=24800, loss=0.1632, time: 14861.06s, 15:09
# Saving checkpoint
# [Epoch 24900] it=24900, loss=0.0348, time: 14920.89s, 15:10
# [Epoch 25000] it=25000, loss=0.0382, time: 14980.57s, 15:11
# Saving checkpoint
# [Epoch 25100] it=25100, loss=-0.0849, time: 15040.26s, 15:12
# [Epoch 25200] it=25200, loss=0.0679, time: 15099.92s, 15:13
# Saving checkpoint
# [Epoch 25300] it=25300, loss=0.0842, time: 15159.65s, 15:14
# [Epoch 25400] it=25400, loss=-0.1037, time: 15219.31s, 15:15
# Saving checkpoint
# [Epoch 25500] it=25500, loss=0.0871, time: 15279.21s, 15:16
# [Epoch 25600] it=25600, loss=0.1114, time: 15339.10s, 15:17
# Saving checkpoint
# [Epoch 25700] it=25700, loss=0.0393, time: 15398.99s, 15:18
# [Epoch 25800] it=25800, loss=0.0375, time: 15458.72s, 15:19
# Saving checkpoint
# [Epoch 25900] it=25900, loss=0.2018, time: 15518.43s, 15:20
# [Epoch 26000] it=26000, loss=0.0861, time: 15578.10s, 15:21
# Saving checkpoint
# [Epoch 26100] it=26100, loss=0.0541, time: 15637.79s, 15:22
# [Epoch 26200] it=26200, loss=0.0630, time: 15697.50s, 15:23
# Saving checkpoint
# [Epoch 26300] it=26300, loss=0.0758, time: 15754.55s, 15:24
# [Epoch 26400] it=26400, loss=-0.2276, time: 15814.38s, 15:25
# Saving checkpoint
# [Epoch 26500] it=26500, loss=-0.2264, time: 15874.34s, 15:26
# [Epoch 26600] it=26600, loss=0.0667, time: 15933.94s, 15:27
# Saving checkpoint
# [Epoch 26700] it=26700, loss=0.0221, time: 15993.74s, 15:27
# [Epoch 26800] it=26800, loss=0.0780, time: 16053.58s, 15:28
# Saving checkpoint
# [Epoch 26900] it=26900, loss=0.0927, time: 16113.44s, 15:29
# [Epoch 27000] it=27000, loss=0.0719, time: 16173.35s, 15:30
# Saving checkpoint
# [Epoch 27100] it=27100, loss=0.0638, time: 16233.39s, 15:31
# [Epoch 27200] it=27200, loss=0.1177, time: 16293.29s, 15:32
# Saving checkpoint
# [Epoch 27300] it=27300, loss=-0.0348, time: 16353.24s, 15:33
# [Epoch 27400] it=27400, loss=0.0176, time: 16413.27s, 15:34
# Saving checkpoint
# [Epoch 27500] it=27500, loss=0.1144, time: 16473.17s, 15:35
# [Epoch 27600] it=27600, loss=0.1815, time: 16532.94s, 15:36
# Saving checkpoint
# [Epoch 27700] it=27700, loss=0.0300, time: 16590.77s, 15:37
# [Epoch 27800] it=27800, loss=0.1117, time: 16647.20s, 15:38
# Saving checkpoint
# [Epoch 27900] it=27900, loss=0.1561, time: 16706.87s, 15:39
# [Epoch 28000] it=28000, loss=0.1155, time: 16766.42s, 15:40
# Saving checkpoint
# Backup checkpoint
# [Epoch 28100] it=28100, loss=0.1371, time: 16826.24s, 15:41
# [Epoch 28200] it=28200, loss=-0.1012, time: 16885.90s, 15:42
# Saving checkpoint
# [Epoch 28300] it=28300, loss=0.1379, time: 16945.56s, 15:43
# [Epoch 28400] it=28400, loss=0.1379, time: 17005.19s, 15:44
# Saving checkpoint
# [Epoch 28500] it=28500, loss=0.1310, time: 17065.02s, 15:45
# [Epoch 28600] it=28600, loss=0.1484, time: 17124.81s, 15:46
# Saving checkpoint
# [Epoch 28700] it=28700, loss=0.0994, time: 17184.66s, 15:47
# [Epoch 28800] it=28800, loss=0.0993, time: 17244.37s, 15:48
# Saving checkpoint
# [Epoch 28900] it=28900, loss=0.0762, time: 17304.11s, 15:49
# [Epoch 29000] it=29000, loss=0.1234, time: 17363.80s, 15:50
# Saving checkpoint
# [Epoch 29100] it=29100, loss=0.2027, time: 17423.37s, 15:51
# [Epoch 29200] it=29200, loss=0.1160, time: 17483.05s, 15:52
# Saving checkpoint
# [Epoch 29300] it=29300, loss=0.1171, time: 17542.92s, 15:53
# [Epoch 29400] it=29400, loss=0.0789, time: 17602.57s, 15:54
# Saving checkpoint
# [Epoch 29500] it=29500, loss=0.1381, time: 17662.47s, 15:55
# [Epoch 29600] it=29600, loss=0.1235, time: 17722.10s, 15:56
# Saving checkpoint
# [Epoch 29700] it=29700, loss=0.1440, time: 17781.89s, 15:57
# [Epoch 29800] it=29800, loss=0.1377, time: 17841.59s, 15:58
# Saving checkpoint
# [Epoch 29900] it=29900, loss=0.1432, time: 17901.40s, 15:59
# [Epoch 30000] it=30000, loss=0.1026, time: 17961.16s, 16:00
# Saving checkpoint
